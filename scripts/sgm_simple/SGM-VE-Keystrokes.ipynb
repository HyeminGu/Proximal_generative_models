# %% [markdown]
# # Score-based Generative Modeling with SDEs (Simple examples)

# %%
import os
# Out:
# '/Users/hyemin/Documents/source_code/Proximal_generative_models/scripts/sgm_simple-benjamin'

# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import torch.nn as nn
import lib.toy_data as toy_data
import numpy as np
import pickle

# %% [markdown]
# Basic parameters

# %%
learning_rate = 1e-3 # learning rate for training neural network
batch_size = 7160  # batch size during training of neural network
N_samples = 7160
epochs = 100000   # Number of training epochs for the neural network
sigma_max = 500.0 
sigma_min = 0.01  
T = 1    # Forward simulation time in the forward SDE (fixed)
dataset = 'Keystrokes' # Dataset choice, see toy_data for full options of toy datasets 
d = 1

# %% [markdown]
# We first initialize the neural net that models the score function.

# %%
## Model construction

class DenoisingModel(nn.Module):
    
    def __init__(self, hidden_units=32):
        super(DenoisingModel, self).__init__()
        # hidden_units = 32
        
        # data and timestep
        self.fc1 = nn.Linear(d+1, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc1.weight)
        self.activation1 = nn.GELU()
        self.fc2 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc2.weight)
        self.activation2 = nn.GELU()
        self.fc3 = nn.Linear(int(hidden_units), d+1, bias=True)
        nn.init.xavier_uniform_(self.fc3.weight)
        self.activation3 = nn.GELU()
        
        self.fc4 = nn.Linear(d+1, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc4.weight)
        self.activation4 = nn.GELU()
        self.fc5 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc5.weight)
        self.activation5 = nn.GELU()
        self.fc6 = nn.Linear(int(hidden_units), d+1, bias=True)
        nn.init.xavier_uniform_(self.fc6.weight)
        self.activation6 = nn.GELU()
        
        self.fc7 = nn.Linear(d+1, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc7.weight)
        self.activation7 = nn.GELU()
        self.fc8 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc8.weight)
        self.activation8 = nn.GELU()
        self.fc9 = nn.Linear(int(hidden_units), d, bias=True)
        nn.init.xavier_uniform_(self.fc9.weight)
        
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.activation1(x)
        x = self.fc2(x)
        x = self.activation2(x)
        x = self.fc3(x)
        x = self.activation3(x)
        x = self.fc4(x)
        x = self.activation4(x)
        x = self.fc5(x)
        x = self.activation5(x)
        x = self.fc6(x)
        x = self.activation6(x)
        x = self.fc7(x)
        x = self.activation7(x)
        x = self.fc8(x)
        x = self.activation8(x)
        x = self.fc9(x)
        
        return x
      
scorenet = DenoisingModel()
print(scorenet)
optimizer = optim.Adam(scorenet.parameters(), lr=learning_rate)
# Out:
# DenoisingModel(
#   (fc1): Linear(in_features=2, out_features=32, bias=True)
#   (activation1): GELU(approximate='none')
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (activation2): GELU(approximate='none')
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
#   (activation3): GELU(approximate='none')
#   (fc4): Linear(in_features=2, out_features=32, bias=True)
#   (activation4): GELU(approximate='none')
#   (fc5): Linear(in_features=32, out_features=32, bias=True)
#   (activation5): GELU(approximate='none')
#   (fc6): Linear(in_features=32, out_features=2, bias=True)
#   (activation6): GELU(approximate='none')
#   (fc7): Linear(in_features=2, out_features=32, bias=True)
#   (activation7): GELU(approximate='none')
#   (fc8): Linear(in_features=32, out_features=32, bias=True)
#   (activation8): GELU(approximate='none')
#   (fc9): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# Define loss functions. These loss functions assume that the forward process is a standard OU process dx = -x/2 dt + dW. The choice of \lambda(t) in the SGM objective function is equal to 1 (the constant in front of the dW term).

# %%
# Loss function -- we use the denoising diffusions objective function
# Scorenet is the score model, samples are the training samples, Tmin/Tmax are the time interval that is being trained on, and eps is so that Tmin is not sampled. 

def time_dsm_score_estimator(scorenet,samples,sigma_min,sigma_max,Tmin,Tmax,eps):

    t = torch.rand(samples.shape[0]) * (Tmax - Tmin - eps) + eps + Tmin # sample uniformly from time interval

    # Add noise to the training samples
    z = torch.randn_like(samples)
    sigmas = sigma_min * (sigma_max/sigma_min)**((t - Tmin)/(Tmax - Tmin))
    sigmas = sigmas.view(samples.shape[0],*([1]*len(samples.shape[1:])))
    noise = z * sigmas
    #tenlarge = t.repeat(2,1).T
    perturbed_samples = samples + noise

    # Evaluate score and marginal score on the perturbed samples
    #target = - 1/ (sigmas ** 2) * (noise)
    score_eval_samples = torch.cat((t.reshape(-1,1),perturbed_samples),1)
    scores = scorenet(score_eval_samples)

    # Evaluate the loss function 
    #target = target.view(target.shape[0],-1)
    scores = scores.view(scores.shape[0],-1)
    loss = 0.5 * ((scores * sigmas + z) ** 2).sum(dim = -1) 

    return loss.mean(dim = 0)


# Loss function
# This is for if you have a specific mesh for the time interval you would like the network to train on. 
def deterministic_time_dsm_score_estimator(scorenet,samples,t):

    loss = 0
    for ii in range(len(t)-1):

        # Add noise to the training samples
        sigmas = torch.sqrt(1 - torch.exp(-t[ii]))
        noise = torch.randn_like(samples) * sigmas
        perturbed_samples = samples * torch.exp(-0.5 * t[ii]) + noise

        # Evaluate score and marginal score on perturbed samples
        target = - 1/ (sigmas ** 2) * (noise)
        score_eval_samples = torch.cat((t[ii].repeat(perturbed_samples.shape[0],1),perturbed_samples),1)
        scores = scorenet(score_eval_samples)

        # Evaluate loss function at this particular t[ii]
        target = target.view(target.shape[0],-1)
        scores = scores.view(scores.shape[0],-1)
        loss_vec = 0.5 * ((scores-target) ** 2).sum(dim = -1) 
        loss = loss + (t[ii+1]-t[ii])*loss_vec.mean(dim = 0)

    return loss

# %% [markdown]
# Training the score network

# %%
# Training the score network
# sample toy_data
#p_samples_all = toy_data.inf_train_gen(dataset, N_samples)
p_samples = toy_data.inf_train_gen(dataset, N_samples)

for step in range(epochs):
    #for i in range(int(N_samples//batch_size)):
    #    p_samples = p_samples_all[i*batch_size:(i+1)*batch_size,:]
    samples = torch.tensor(p_samples).to(dtype = torch.float32)

    # evaluate loss function and gradient
    loss = time_dsm_score_estimator(scorenet,samples,sigma_min, sigma_max, 0,T,eps = 0.0005)
    optimizer.zero_grad()
    loss.backward()

    # Update score network
    optimizer.step()

    if not step%100:
        print(loss,step)
# Out:
# tensor(29254.3242, grad_fn=<MeanBackward1>) 0
# tensor(1.1315, grad_fn=<MeanBackward1>) 100
# tensor(0.5438, grad_fn=<MeanBackward1>) 200
# tensor(0.5124, grad_fn=<MeanBackward1>) 300
# tensor(0.4768, grad_fn=<MeanBackward1>) 400
# tensor(0.9859, grad_fn=<MeanBackward1>) 500
# tensor(0.4715, grad_fn=<MeanBackward1>) 600
# tensor(0.4680, grad_fn=<MeanBackward1>) 700
# tensor(0.4754, grad_fn=<MeanBackward1>) 800
# tensor(0.4758, grad_fn=<MeanBackward1>) 900
# tensor(0.4635, grad_fn=<MeanBackward1>) 1000
# tensor(0.4663, grad_fn=<MeanBackward1>) 1100
# tensor(0.4801, grad_fn=<MeanBackward1>) 1200
# tensor(0.4829, grad_fn=<MeanBackward1>) 1300
# tensor(0.4697, grad_fn=<MeanBackward1>) 1400
# tensor(0.4733, grad_fn=<MeanBackward1>) 1500
# tensor(0.4775, grad_fn=<MeanBackward1>) 1600
# tensor(0.4632, grad_fn=<MeanBackward1>) 1700
# tensor(0.4745, grad_fn=<MeanBackward1>) 1800
# tensor(0.4643, grad_fn=<MeanBackward1>) 1900
# tensor(0.4657, grad_fn=<MeanBackward1>) 2000
# tensor(0.4571, grad_fn=<MeanBackward1>) 2100
# tensor(0.4557, grad_fn=<MeanBackward1>) 2200
# tensor(0.4726, grad_fn=<MeanBackward1>) 2300
# tensor(0.5127, grad_fn=<MeanBackward1>) 2400
# tensor(0.4734, grad_fn=<MeanBackward1>) 2500
# tensor(0.4788, grad_fn=<MeanBackward1>) 2600
# tensor(0.4644, grad_fn=<MeanBackward1>) 2700
# tensor(0.4557, grad_fn=<MeanBackward1>) 2800
# tensor(0.4635, grad_fn=<MeanBackward1>) 2900
# tensor(0.4779, grad_fn=<MeanBackward1>) 3000
# tensor(0.4757, grad_fn=<MeanBackward1>) 3100
# tensor(0.4693, grad_fn=<MeanBackward1>) 3200
# tensor(0.4613, grad_fn=<MeanBackward1>) 3300
# tensor(0.4706, grad_fn=<MeanBackward1>) 3400
# tensor(0.4563, grad_fn=<MeanBackward1>) 3500
# tensor(0.4416, grad_fn=<MeanBackward1>) 3600
# tensor(0.4732, grad_fn=<MeanBackward1>) 3700
# tensor(0.4706, grad_fn=<MeanBackward1>) 3800
# tensor(0.4604, grad_fn=<MeanBackward1>) 3900
# tensor(0.4794, grad_fn=<MeanBackward1>) 4000
# tensor(0.4473, grad_fn=<MeanBackward1>) 4100
# tensor(0.4524, grad_fn=<MeanBackward1>) 4200
# tensor(0.4596, grad_fn=<MeanBackward1>) 4300
# tensor(0.4674, grad_fn=<MeanBackward1>) 4400
# tensor(0.4618, grad_fn=<MeanBackward1>) 4500
# tensor(0.4671, grad_fn=<MeanBackward1>) 4600
# tensor(0.4792, grad_fn=<MeanBackward1>) 4700
# tensor(0.4574, grad_fn=<MeanBackward1>) 4800
# tensor(0.4632, grad_fn=<MeanBackward1>) 4900
# tensor(0.4547, grad_fn=<MeanBackward1>) 5000
# tensor(0.4615, grad_fn=<MeanBackward1>) 5100
# tensor(0.4595, grad_fn=<MeanBackward1>) 5200
# tensor(0.4583, grad_fn=<MeanBackward1>) 5300
# tensor(0.4646, grad_fn=<MeanBackward1>) 5400
# tensor(0.4574, grad_fn=<MeanBackward1>) 5500
# tensor(0.4700, grad_fn=<MeanBackward1>) 5600
# tensor(0.4592, grad_fn=<MeanBackward1>) 5700
# tensor(0.4604, grad_fn=<MeanBackward1>) 5800
# tensor(0.4694, grad_fn=<MeanBackward1>) 5900
# tensor(0.4496, grad_fn=<MeanBackward1>) 6000
# tensor(0.4598, grad_fn=<MeanBackward1>) 6100
# tensor(0.4609, grad_fn=<MeanBackward1>) 6200
# tensor(0.4628, grad_fn=<MeanBackward1>) 6300
# tensor(0.4574, grad_fn=<MeanBackward1>) 6400
# tensor(0.4601, grad_fn=<MeanBackward1>) 6500
# tensor(0.4759, grad_fn=<MeanBackward1>) 6600
# tensor(0.4765, grad_fn=<MeanBackward1>) 6700
# tensor(0.4430, grad_fn=<MeanBackward1>) 6800
# tensor(0.4647, grad_fn=<MeanBackward1>) 6900
# tensor(0.4572, grad_fn=<MeanBackward1>) 7000
# tensor(0.4639, grad_fn=<MeanBackward1>) 7100
# tensor(0.4682, grad_fn=<MeanBackward1>) 7200
# tensor(0.4564, grad_fn=<MeanBackward1>) 7300
# tensor(0.4573, grad_fn=<MeanBackward1>) 7400
# tensor(0.4606, grad_fn=<MeanBackward1>) 7500
# tensor(0.4557, grad_fn=<MeanBackward1>) 7600
# tensor(0.4631, grad_fn=<MeanBackward1>) 7700
# tensor(0.4676, grad_fn=<MeanBackward1>) 7800
# tensor(0.4705, grad_fn=<MeanBackward1>) 7900
# tensor(0.4557, grad_fn=<MeanBackward1>) 8000
# tensor(0.4463, grad_fn=<MeanBackward1>) 8100
# tensor(0.4624, grad_fn=<MeanBackward1>) 8200
# tensor(0.4675, grad_fn=<MeanBackward1>) 8300
# tensor(0.4619, grad_fn=<MeanBackward1>) 8400
# tensor(0.4673, grad_fn=<MeanBackward1>) 8500
# tensor(0.4647, grad_fn=<MeanBackward1>) 8600
# tensor(0.4499, grad_fn=<MeanBackward1>) 8700
# tensor(0.4772, grad_fn=<MeanBackward1>) 8800
# tensor(0.4639, grad_fn=<MeanBackward1>) 8900
# tensor(0.4656, grad_fn=<MeanBackward1>) 9000
# tensor(0.4640, grad_fn=<MeanBackward1>) 9100
# tensor(0.4543, grad_fn=<MeanBackward1>) 9200
# tensor(0.4554, grad_fn=<MeanBackward1>) 9300
# tensor(0.4627, grad_fn=<MeanBackward1>) 9400
# tensor(0.4655, grad_fn=<MeanBackward1>) 9500
# tensor(0.4572, grad_fn=<MeanBackward1>) 9600
# tensor(0.4632, grad_fn=<MeanBackward1>) 9700
# tensor(0.4642, grad_fn=<MeanBackward1>) 9800
# tensor(0.4738, grad_fn=<MeanBackward1>) 9900
# tensor(0.4545, grad_fn=<MeanBackward1>) 10000
# tensor(0.4626, grad_fn=<MeanBackward1>) 10100
# tensor(0.4573, grad_fn=<MeanBackward1>) 10200
# tensor(0.4637, grad_fn=<MeanBackward1>) 10300
# tensor(0.4644, grad_fn=<MeanBackward1>) 10400
# tensor(0.4698, grad_fn=<MeanBackward1>) 10500
# tensor(0.4690, grad_fn=<MeanBackward1>) 10600
# tensor(0.4576, grad_fn=<MeanBackward1>) 10700
# tensor(0.4647, grad_fn=<MeanBackward1>) 10800
# tensor(0.4719, grad_fn=<MeanBackward1>) 10900
# tensor(0.4672, grad_fn=<MeanBackward1>) 11000
# tensor(0.4719, grad_fn=<MeanBackward1>) 11100
# tensor(0.4688, grad_fn=<MeanBackward1>) 11200
# tensor(0.4507, grad_fn=<MeanBackward1>) 11300
# tensor(0.4646, grad_fn=<MeanBackward1>) 11400
# tensor(0.4652, grad_fn=<MeanBackward1>) 11500
# tensor(0.4673, grad_fn=<MeanBackward1>) 11600
# tensor(0.4617, grad_fn=<MeanBackward1>) 11700
# tensor(0.4643, grad_fn=<MeanBackward1>) 11800
# tensor(0.4587, grad_fn=<MeanBackward1>) 11900
# tensor(0.4733, grad_fn=<MeanBackward1>) 12000
# tensor(0.4606, grad_fn=<MeanBackward1>) 12100
# tensor(0.4697, grad_fn=<MeanBackward1>) 12200
# tensor(0.4568, grad_fn=<MeanBackward1>) 12300
# tensor(0.4670, grad_fn=<MeanBackward1>) 12400
# tensor(0.4865, grad_fn=<MeanBackward1>) 12500
# tensor(0.4599, grad_fn=<MeanBackward1>) 12600
# tensor(0.4616, grad_fn=<MeanBackward1>) 12700
# tensor(0.4702, grad_fn=<MeanBackward1>) 12800
# tensor(0.4686, grad_fn=<MeanBackward1>) 12900
# tensor(0.4660, grad_fn=<MeanBackward1>) 13000
# tensor(0.4601, grad_fn=<MeanBackward1>) 13100
# tensor(0.4655, grad_fn=<MeanBackward1>) 13200
# tensor(0.4649, grad_fn=<MeanBackward1>) 13300
# tensor(0.4568, grad_fn=<MeanBackward1>) 13400
# tensor(0.4647, grad_fn=<MeanBackward1>) 13500
# tensor(0.4638, grad_fn=<MeanBackward1>) 13600
# tensor(0.4649, grad_fn=<MeanBackward1>) 13700
# tensor(0.4676, grad_fn=<MeanBackward1>) 13800
# tensor(0.4688, grad_fn=<MeanBackward1>) 13900
# tensor(0.4593, grad_fn=<MeanBackward1>) 14000
# tensor(0.4573, grad_fn=<MeanBackward1>) 14100
# tensor(0.4474, grad_fn=<MeanBackward1>) 14200
# tensor(0.4831, grad_fn=<MeanBackward1>) 14300
# tensor(0.4544, grad_fn=<MeanBackward1>) 14400
# tensor(0.4708, grad_fn=<MeanBackward1>) 14500
# tensor(0.4620, grad_fn=<MeanBackward1>) 14600
# tensor(0.4789, grad_fn=<MeanBackward1>) 14700
# tensor(0.4616, grad_fn=<MeanBackward1>) 14800
# tensor(0.4752, grad_fn=<MeanBackward1>) 14900
# tensor(0.4745, grad_fn=<MeanBackward1>) 15000
# tensor(0.4669, grad_fn=<MeanBackward1>) 15100
# tensor(0.4594, grad_fn=<MeanBackward1>) 15200
# tensor(0.4508, grad_fn=<MeanBackward1>) 15300
# tensor(0.4603, grad_fn=<MeanBackward1>) 15400
# tensor(0.4707, grad_fn=<MeanBackward1>) 15500
# tensor(0.4792, grad_fn=<MeanBackward1>) 15600
# tensor(0.4590, grad_fn=<MeanBackward1>) 15700
# tensor(0.4668, grad_fn=<MeanBackward1>) 15800
# tensor(0.4737, grad_fn=<MeanBackward1>) 15900
# tensor(0.4634, grad_fn=<MeanBackward1>) 16000
# tensor(0.4611, grad_fn=<MeanBackward1>) 16100
# tensor(0.4694, grad_fn=<MeanBackward1>) 16200
# tensor(0.4493, grad_fn=<MeanBackward1>) 16300
# tensor(0.4611, grad_fn=<MeanBackward1>) 16400
# tensor(0.4803, grad_fn=<MeanBackward1>) 16500
# tensor(0.4677, grad_fn=<MeanBackward1>) 16600
# tensor(0.4686, grad_fn=<MeanBackward1>) 16700
# tensor(0.4611, grad_fn=<MeanBackward1>) 16800
# tensor(0.4705, grad_fn=<MeanBackward1>) 16900
# tensor(0.4486, grad_fn=<MeanBackward1>) 17000
# tensor(0.4544, grad_fn=<MeanBackward1>) 17100
# tensor(0.4727, grad_fn=<MeanBackward1>) 17200
# tensor(0.4664, grad_fn=<MeanBackward1>) 17300
# tensor(0.4529, grad_fn=<MeanBackward1>) 17400
# tensor(0.4561, grad_fn=<MeanBackward1>) 17500
# tensor(0.4650, grad_fn=<MeanBackward1>) 17600
# tensor(0.4541, grad_fn=<MeanBackward1>) 17700
# tensor(0.4617, grad_fn=<MeanBackward1>) 17800
# tensor(0.4643, grad_fn=<MeanBackward1>) 17900
# tensor(0.4777, grad_fn=<MeanBackward1>) 18000
# tensor(0.4740, grad_fn=<MeanBackward1>) 18100
# tensor(0.4529, grad_fn=<MeanBackward1>) 18200
# tensor(0.4612, grad_fn=<MeanBackward1>) 18300
# tensor(0.4753, grad_fn=<MeanBackward1>) 18400
# tensor(0.4615, grad_fn=<MeanBackward1>) 18500
# tensor(0.4706, grad_fn=<MeanBackward1>) 18600
# tensor(0.4589, grad_fn=<MeanBackward1>) 18700
# tensor(0.4624, grad_fn=<MeanBackward1>) 18800
# tensor(0.4543, grad_fn=<MeanBackward1>) 18900
# tensor(0.4609, grad_fn=<MeanBackward1>) 19000
# tensor(0.4596, grad_fn=<MeanBackward1>) 19100
# tensor(0.4644, grad_fn=<MeanBackward1>) 19200
# tensor(0.4860, grad_fn=<MeanBackward1>) 19300
# tensor(0.4649, grad_fn=<MeanBackward1>) 19400
# tensor(0.4658, grad_fn=<MeanBackward1>) 19500
# tensor(0.4673, grad_fn=<MeanBackward1>) 19600
# tensor(0.4628, grad_fn=<MeanBackward1>) 19700
# tensor(0.4706, grad_fn=<MeanBackward1>) 19800
# tensor(0.4687, grad_fn=<MeanBackward1>) 19900
# tensor(0.4714, grad_fn=<MeanBackward1>) 20000
# tensor(0.4535, grad_fn=<MeanBackward1>) 20100
# tensor(0.4766, grad_fn=<MeanBackward1>) 20200
# tensor(0.4670, grad_fn=<MeanBackward1>) 20300
# tensor(0.4492, grad_fn=<MeanBackward1>) 20400
# tensor(0.4640, grad_fn=<MeanBackward1>) 20500
# tensor(0.4705, grad_fn=<MeanBackward1>) 20600
# tensor(0.4612, grad_fn=<MeanBackward1>) 20700
# tensor(0.4645, grad_fn=<MeanBackward1>) 20800
# tensor(0.4815, grad_fn=<MeanBackward1>) 20900
# tensor(0.4517, grad_fn=<MeanBackward1>) 21000
# tensor(0.4646, grad_fn=<MeanBackward1>) 21100
# tensor(0.4625, grad_fn=<MeanBackward1>) 21200
# tensor(0.4718, grad_fn=<MeanBackward1>) 21300
# tensor(0.4766, grad_fn=<MeanBackward1>) 21400
# tensor(0.4736, grad_fn=<MeanBackward1>) 21500
# tensor(0.4674, grad_fn=<MeanBackward1>) 21600
# tensor(0.4678, grad_fn=<MeanBackward1>) 21700
# tensor(0.4599, grad_fn=<MeanBackward1>) 21800
# tensor(0.4679, grad_fn=<MeanBackward1>) 21900
# tensor(0.4617, grad_fn=<MeanBackward1>) 22000
# tensor(0.4800, grad_fn=<MeanBackward1>) 22100
# tensor(0.4656, grad_fn=<MeanBackward1>) 22200
# tensor(0.4564, grad_fn=<MeanBackward1>) 22300
# tensor(0.4573, grad_fn=<MeanBackward1>) 22400
# tensor(0.4659, grad_fn=<MeanBackward1>) 22500
# tensor(0.4561, grad_fn=<MeanBackward1>) 22600
# tensor(0.4665, grad_fn=<MeanBackward1>) 22700
# tensor(0.4600, grad_fn=<MeanBackward1>) 22800
# tensor(0.4668, grad_fn=<MeanBackward1>) 22900
# tensor(0.4561, grad_fn=<MeanBackward1>) 23000
# tensor(0.4624, grad_fn=<MeanBackward1>) 23100
# tensor(0.4756, grad_fn=<MeanBackward1>) 23200
# tensor(0.4746, grad_fn=<MeanBackward1>) 23300
# tensor(0.4592, grad_fn=<MeanBackward1>) 23400
# tensor(0.4720, grad_fn=<MeanBackward1>) 23500
# tensor(0.4697, grad_fn=<MeanBackward1>) 23600
# tensor(0.4608, grad_fn=<MeanBackward1>) 23700
# tensor(0.4733, grad_fn=<MeanBackward1>) 23800
# tensor(0.4630, grad_fn=<MeanBackward1>) 23900
# tensor(0.4776, grad_fn=<MeanBackward1>) 24000
# tensor(0.4769, grad_fn=<MeanBackward1>) 24100
# tensor(0.4608, grad_fn=<MeanBackward1>) 24200
# tensor(0.4507, grad_fn=<MeanBackward1>) 24300
# tensor(0.4831, grad_fn=<MeanBackward1>) 24400
# tensor(0.4651, grad_fn=<MeanBackward1>) 24500
# tensor(0.4715, grad_fn=<MeanBackward1>) 24600
# tensor(0.4743, grad_fn=<MeanBackward1>) 24700
# tensor(0.4569, grad_fn=<MeanBackward1>) 24800
# tensor(0.4691, grad_fn=<MeanBackward1>) 24900
# tensor(0.4582, grad_fn=<MeanBackward1>) 25000
# tensor(0.4542, grad_fn=<MeanBackward1>) 25100
# tensor(0.4692, grad_fn=<MeanBackward1>) 25200
# tensor(0.4632, grad_fn=<MeanBackward1>) 25300
# tensor(0.4542, grad_fn=<MeanBackward1>) 25400
# tensor(0.4695, grad_fn=<MeanBackward1>) 25500
# tensor(0.4582, grad_fn=<MeanBackward1>) 25600
# tensor(0.4609, grad_fn=<MeanBackward1>) 25700
# tensor(0.4671, grad_fn=<MeanBackward1>) 25800
# tensor(0.4659, grad_fn=<MeanBackward1>) 25900
# tensor(0.4723, grad_fn=<MeanBackward1>) 26000
# tensor(0.4696, grad_fn=<MeanBackward1>) 26100
# tensor(0.4545, grad_fn=<MeanBackward1>) 26200
# tensor(0.4679, grad_fn=<MeanBackward1>) 26300
# tensor(0.4668, grad_fn=<MeanBackward1>) 26400
# tensor(0.4591, grad_fn=<MeanBackward1>) 26500
# tensor(0.4534, grad_fn=<MeanBackward1>) 26600
# tensor(0.4528, grad_fn=<MeanBackward1>) 26700
# tensor(0.4713, grad_fn=<MeanBackward1>) 26800
# tensor(0.4755, grad_fn=<MeanBackward1>) 26900
# tensor(0.4722, grad_fn=<MeanBackward1>) 27000
# tensor(0.4726, grad_fn=<MeanBackward1>) 27100
# tensor(0.4610, grad_fn=<MeanBackward1>) 27200
# tensor(0.4622, grad_fn=<MeanBackward1>) 27300
# tensor(0.4581, grad_fn=<MeanBackward1>) 27400
# tensor(0.4650, grad_fn=<MeanBackward1>) 27500
# tensor(0.4719, grad_fn=<MeanBackward1>) 27600
# tensor(0.4576, grad_fn=<MeanBackward1>) 27700
# tensor(0.4683, grad_fn=<MeanBackward1>) 27800
# tensor(0.4676, grad_fn=<MeanBackward1>) 27900
# tensor(0.4609, grad_fn=<MeanBackward1>) 28000
# tensor(0.4652, grad_fn=<MeanBackward1>) 28100
# tensor(0.4652, grad_fn=<MeanBackward1>) 28200
# tensor(0.4651, grad_fn=<MeanBackward1>) 28300
# tensor(0.4630, grad_fn=<MeanBackward1>) 28400
# tensor(0.4701, grad_fn=<MeanBackward1>) 28500
# tensor(0.4596, grad_fn=<MeanBackward1>) 28600
# tensor(0.4477, grad_fn=<MeanBackward1>) 28700
# tensor(0.4785, grad_fn=<MeanBackward1>) 28800
# tensor(0.4599, grad_fn=<MeanBackward1>) 28900
# tensor(0.4645, grad_fn=<MeanBackward1>) 29000
# tensor(0.4844, grad_fn=<MeanBackward1>) 29100
# tensor(0.4580, grad_fn=<MeanBackward1>) 29200
# tensor(0.4457, grad_fn=<MeanBackward1>) 29300
# tensor(0.4507, grad_fn=<MeanBackward1>) 29400
# tensor(0.4702, grad_fn=<MeanBackward1>) 29500
# tensor(0.4726, grad_fn=<MeanBackward1>) 29600
# tensor(0.4650, grad_fn=<MeanBackward1>) 29700
# tensor(0.4743, grad_fn=<MeanBackward1>) 29800
# tensor(0.4761, grad_fn=<MeanBackward1>) 29900
# tensor(0.4626, grad_fn=<MeanBackward1>) 30000
# tensor(0.4668, grad_fn=<MeanBackward1>) 30100
# tensor(0.4595, grad_fn=<MeanBackward1>) 30200
# tensor(0.4566, grad_fn=<MeanBackward1>) 30300
# tensor(0.4603, grad_fn=<MeanBackward1>) 30400
# tensor(0.4752, grad_fn=<MeanBackward1>) 30500
# tensor(0.4660, grad_fn=<MeanBackward1>) 30600
# tensor(0.4522, grad_fn=<MeanBackward1>) 30700
# tensor(0.4530, grad_fn=<MeanBackward1>) 30800
# tensor(0.4742, grad_fn=<MeanBackward1>) 30900
# tensor(0.4512, grad_fn=<MeanBackward1>) 31000
# tensor(0.4643, grad_fn=<MeanBackward1>) 31100
# tensor(0.4733, grad_fn=<MeanBackward1>) 31200
# tensor(0.4457, grad_fn=<MeanBackward1>) 31300
# tensor(0.4686, grad_fn=<MeanBackward1>) 31400
# tensor(0.4659, grad_fn=<MeanBackward1>) 31500
# tensor(0.4536, grad_fn=<MeanBackward1>) 31600
# tensor(0.4640, grad_fn=<MeanBackward1>) 31700
# tensor(0.4795, grad_fn=<MeanBackward1>) 31800
# tensor(0.4600, grad_fn=<MeanBackward1>) 31900
# tensor(0.4533, grad_fn=<MeanBackward1>) 32000
# tensor(0.4700, grad_fn=<MeanBackward1>) 32100
# tensor(0.4703, grad_fn=<MeanBackward1>) 32200
# tensor(0.4516, grad_fn=<MeanBackward1>) 32300
# tensor(0.4611, grad_fn=<MeanBackward1>) 32400
# tensor(0.4648, grad_fn=<MeanBackward1>) 32500
# tensor(0.4795, grad_fn=<MeanBackward1>) 32600
# tensor(0.4672, grad_fn=<MeanBackward1>) 32700
# tensor(0.4677, grad_fn=<MeanBackward1>) 32800
# tensor(0.4539, grad_fn=<MeanBackward1>) 32900
# tensor(0.4721, grad_fn=<MeanBackward1>) 33000
# tensor(0.4715, grad_fn=<MeanBackward1>) 33100
# tensor(0.4613, grad_fn=<MeanBackward1>) 33200
# tensor(0.4491, grad_fn=<MeanBackward1>) 33300
# tensor(0.4735, grad_fn=<MeanBackward1>) 33400
# tensor(0.4533, grad_fn=<MeanBackward1>) 33500
# tensor(0.4689, grad_fn=<MeanBackward1>) 33600
# tensor(0.4666, grad_fn=<MeanBackward1>) 33700
# tensor(0.4614, grad_fn=<MeanBackward1>) 33800
# tensor(0.4646, grad_fn=<MeanBackward1>) 33900
# tensor(0.4470, grad_fn=<MeanBackward1>) 34000
# tensor(0.4553, grad_fn=<MeanBackward1>) 34100
# tensor(0.4721, grad_fn=<MeanBackward1>) 34200
# tensor(0.4639, grad_fn=<MeanBackward1>) 34300
# tensor(0.4580, grad_fn=<MeanBackward1>) 34400
# tensor(0.4585, grad_fn=<MeanBackward1>) 34500
# tensor(0.4518, grad_fn=<MeanBackward1>) 34600
# tensor(0.4640, grad_fn=<MeanBackward1>) 34700
# tensor(0.4705, grad_fn=<MeanBackward1>) 34800
# tensor(0.4630, grad_fn=<MeanBackward1>) 34900
# tensor(0.4711, grad_fn=<MeanBackward1>) 35000
# tensor(0.4668, grad_fn=<MeanBackward1>) 35100
# tensor(0.4597, grad_fn=<MeanBackward1>) 35200
# tensor(0.4631, grad_fn=<MeanBackward1>) 35300
# tensor(0.4739, grad_fn=<MeanBackward1>) 35400
# tensor(0.4760, grad_fn=<MeanBackward1>) 35500
# tensor(0.4738, grad_fn=<MeanBackward1>) 35600
# tensor(0.4695, grad_fn=<MeanBackward1>) 35700
# tensor(0.4842, grad_fn=<MeanBackward1>) 35800
# tensor(0.4710, grad_fn=<MeanBackward1>) 35900
# tensor(0.4725, grad_fn=<MeanBackward1>) 36000
# tensor(0.4620, grad_fn=<MeanBackward1>) 36100
# tensor(0.4564, grad_fn=<MeanBackward1>) 36200
# tensor(0.4834, grad_fn=<MeanBackward1>) 36300
# tensor(0.4584, grad_fn=<MeanBackward1>) 36400
# tensor(0.4542, grad_fn=<MeanBackward1>) 36500
# tensor(0.4570, grad_fn=<MeanBackward1>) 36600
# tensor(0.4606, grad_fn=<MeanBackward1>) 36700
# tensor(0.4631, grad_fn=<MeanBackward1>) 36800
# tensor(0.4636, grad_fn=<MeanBackward1>) 36900
# tensor(0.4902, grad_fn=<MeanBackward1>) 37000
# tensor(0.4670, grad_fn=<MeanBackward1>) 37100
# tensor(0.4565, grad_fn=<MeanBackward1>) 37200
# tensor(0.4644, grad_fn=<MeanBackward1>) 37300
# tensor(0.4573, grad_fn=<MeanBackward1>) 37400
# tensor(0.4829, grad_fn=<MeanBackward1>) 37500
# tensor(0.4557, grad_fn=<MeanBackward1>) 37600
# tensor(0.4589, grad_fn=<MeanBackward1>) 37700
# tensor(0.4554, grad_fn=<MeanBackward1>) 37800
# tensor(0.4824, grad_fn=<MeanBackward1>) 37900
# tensor(0.4994, grad_fn=<MeanBackward1>) 38000
# tensor(0.5117, grad_fn=<MeanBackward1>) 38100
# tensor(0.4836, grad_fn=<MeanBackward1>) 38200
# tensor(0.5228, grad_fn=<MeanBackward1>) 38300
# tensor(0.5065, grad_fn=<MeanBackward1>) 38400
# tensor(0.5016, grad_fn=<MeanBackward1>) 38500
# tensor(0.4939, grad_fn=<MeanBackward1>) 38600
# tensor(0.4623, grad_fn=<MeanBackward1>) 38700
# tensor(0.4629, grad_fn=<MeanBackward1>) 38800
# tensor(0.4713, grad_fn=<MeanBackward1>) 38900
# tensor(0.4649, grad_fn=<MeanBackward1>) 39000
# tensor(0.4738, grad_fn=<MeanBackward1>) 39100
# tensor(0.4512, grad_fn=<MeanBackward1>) 39200
# tensor(0.4648, grad_fn=<MeanBackward1>) 39300
# tensor(0.4684, grad_fn=<MeanBackward1>) 39400
# tensor(0.4571, grad_fn=<MeanBackward1>) 39500
# tensor(0.4639, grad_fn=<MeanBackward1>) 39600
# tensor(0.4542, grad_fn=<MeanBackward1>) 39700
# tensor(0.4739, grad_fn=<MeanBackward1>) 39800
# tensor(0.4672, grad_fn=<MeanBackward1>) 39900
# tensor(0.4580, grad_fn=<MeanBackward1>) 40000
# tensor(0.4529, grad_fn=<MeanBackward1>) 40100
# tensor(0.4493, grad_fn=<MeanBackward1>) 40200
# tensor(0.4676, grad_fn=<MeanBackward1>) 40300
# tensor(0.4829, grad_fn=<MeanBackward1>) 40400
# tensor(0.4838, grad_fn=<MeanBackward1>) 40500
# tensor(0.4570, grad_fn=<MeanBackward1>) 40600
# tensor(0.4463, grad_fn=<MeanBackward1>) 40700
# tensor(0.4597, grad_fn=<MeanBackward1>) 40800
# tensor(0.4812, grad_fn=<MeanBackward1>) 40900
# tensor(0.4636, grad_fn=<MeanBackward1>) 41000
# tensor(0.4496, grad_fn=<MeanBackward1>) 41100
# tensor(0.4554, grad_fn=<MeanBackward1>) 41200
# tensor(0.4639, grad_fn=<MeanBackward1>) 41300
# tensor(0.4554, grad_fn=<MeanBackward1>) 41400
# tensor(0.4778, grad_fn=<MeanBackward1>) 41500
# tensor(0.4886, grad_fn=<MeanBackward1>) 41600
# tensor(0.4559, grad_fn=<MeanBackward1>) 41700
# tensor(0.4707, grad_fn=<MeanBackward1>) 41800
# tensor(0.4580, grad_fn=<MeanBackward1>) 41900
# tensor(0.4541, grad_fn=<MeanBackward1>) 42000
# tensor(0.4508, grad_fn=<MeanBackward1>) 42100
# tensor(0.4561, grad_fn=<MeanBackward1>) 42200
# tensor(0.4611, grad_fn=<MeanBackward1>) 42300
# tensor(0.4640, grad_fn=<MeanBackward1>) 42400
# tensor(0.4657, grad_fn=<MeanBackward1>) 42500
# tensor(0.4861, grad_fn=<MeanBackward1>) 42600
# tensor(0.4862, grad_fn=<MeanBackward1>) 42700
# tensor(0.4659, grad_fn=<MeanBackward1>) 42800
# tensor(0.4746, grad_fn=<MeanBackward1>) 42900
# tensor(0.4572, grad_fn=<MeanBackward1>) 43000
# tensor(0.4533, grad_fn=<MeanBackward1>) 43100
# tensor(0.4505, grad_fn=<MeanBackward1>) 43200
# tensor(0.4550, grad_fn=<MeanBackward1>) 43300
# tensor(0.4592, grad_fn=<MeanBackward1>) 43400
# tensor(0.4668, grad_fn=<MeanBackward1>) 43500
# tensor(0.4729, grad_fn=<MeanBackward1>) 43600
# tensor(0.4962, grad_fn=<MeanBackward1>) 43700
# tensor(0.4632, grad_fn=<MeanBackward1>) 43800
# tensor(0.4726, grad_fn=<MeanBackward1>) 43900
# tensor(0.5063, grad_fn=<MeanBackward1>) 44000
# tensor(0.4555, grad_fn=<MeanBackward1>) 44100
# tensor(0.4636, grad_fn=<MeanBackward1>) 44200
# tensor(0.4654, grad_fn=<MeanBackward1>) 44300
# tensor(0.4974, grad_fn=<MeanBackward1>) 44400
# tensor(0.4790, grad_fn=<MeanBackward1>) 44500
# tensor(0.4633, grad_fn=<MeanBackward1>) 44600
# tensor(0.4406, grad_fn=<MeanBackward1>) 44700
# tensor(0.5031, grad_fn=<MeanBackward1>) 44800
# tensor(0.4884, grad_fn=<MeanBackward1>) 44900
# tensor(0.4937, grad_fn=<MeanBackward1>) 45000
# tensor(0.4957, grad_fn=<MeanBackward1>) 45100
# tensor(0.5070, grad_fn=<MeanBackward1>) 45200
# tensor(0.4962, grad_fn=<MeanBackward1>) 45300
# tensor(0.4811, grad_fn=<MeanBackward1>) 45400
# tensor(0.4546, grad_fn=<MeanBackward1>) 45500
# tensor(0.4704, grad_fn=<MeanBackward1>) 45600
# tensor(0.4753, grad_fn=<MeanBackward1>) 45700
# tensor(0.4552, grad_fn=<MeanBackward1>) 45800
# tensor(0.4523, grad_fn=<MeanBackward1>) 45900
# tensor(0.4517, grad_fn=<MeanBackward1>) 46000
# tensor(0.4597, grad_fn=<MeanBackward1>) 46100
# tensor(0.4509, grad_fn=<MeanBackward1>) 46200
# tensor(0.4577, grad_fn=<MeanBackward1>) 46300
# tensor(0.4689, grad_fn=<MeanBackward1>) 46400
# tensor(0.4491, grad_fn=<MeanBackward1>) 46500
# tensor(0.4451, grad_fn=<MeanBackward1>) 46600
# tensor(0.4658, grad_fn=<MeanBackward1>) 46700
# tensor(0.4673, grad_fn=<MeanBackward1>) 46800
# tensor(0.4592, grad_fn=<MeanBackward1>) 46900
# tensor(0.4605, grad_fn=<MeanBackward1>) 47000
# tensor(0.5136, grad_fn=<MeanBackward1>) 47100
# tensor(0.5054, grad_fn=<MeanBackward1>) 47200
# tensor(0.4971, grad_fn=<MeanBackward1>) 47300
# tensor(0.5120, grad_fn=<MeanBackward1>) 47400
# tensor(0.4973, grad_fn=<MeanBackward1>) 47500
# tensor(0.4946, grad_fn=<MeanBackward1>) 47600
# tensor(0.4973, grad_fn=<MeanBackward1>) 47700
# tensor(0.5098, grad_fn=<MeanBackward1>) 47800
# tensor(0.4925, grad_fn=<MeanBackward1>) 47900
# tensor(0.5050, grad_fn=<MeanBackward1>) 48000
# tensor(0.4879, grad_fn=<MeanBackward1>) 48100
# tensor(0.5090, grad_fn=<MeanBackward1>) 48200
# tensor(0.5097, grad_fn=<MeanBackward1>) 48300
# tensor(0.5146, grad_fn=<MeanBackward1>) 48400
# tensor(0.4935, grad_fn=<MeanBackward1>) 48500
# tensor(0.4922, grad_fn=<MeanBackward1>) 48600
# tensor(0.5100, grad_fn=<MeanBackward1>) 48700
# tensor(0.4990, grad_fn=<MeanBackward1>) 48800
# tensor(0.4967, grad_fn=<MeanBackward1>) 48900
# tensor(0.4786, grad_fn=<MeanBackward1>) 49000
# tensor(0.4937, grad_fn=<MeanBackward1>) 49100
# tensor(0.5068, grad_fn=<MeanBackward1>) 49200
# tensor(0.5006, grad_fn=<MeanBackward1>) 49300
# tensor(0.4860, grad_fn=<MeanBackward1>) 49400
# tensor(0.4827, grad_fn=<MeanBackward1>) 49500
# tensor(0.5091, grad_fn=<MeanBackward1>) 49600
# tensor(0.4996, grad_fn=<MeanBackward1>) 49700
# tensor(0.5001, grad_fn=<MeanBackward1>) 49800
# tensor(0.5119, grad_fn=<MeanBackward1>) 49900
# tensor(0.4913, grad_fn=<MeanBackward1>) 50000
# tensor(0.4923, grad_fn=<MeanBackward1>) 50100
# tensor(0.5012, grad_fn=<MeanBackward1>) 50200
# tensor(0.5158, grad_fn=<MeanBackward1>) 50300
# tensor(0.5039, grad_fn=<MeanBackward1>) 50400
# tensor(0.5188, grad_fn=<MeanBackward1>) 50500
# tensor(0.5130, grad_fn=<MeanBackward1>) 50600
# tensor(0.4959, grad_fn=<MeanBackward1>) 50700
# tensor(0.5032, grad_fn=<MeanBackward1>) 50800
# tensor(0.4979, grad_fn=<MeanBackward1>) 50900
# tensor(0.5154, grad_fn=<MeanBackward1>) 51000
# tensor(0.5009, grad_fn=<MeanBackward1>) 51100
# tensor(0.4864, grad_fn=<MeanBackward1>) 51200
# tensor(0.4954, grad_fn=<MeanBackward1>) 51300
# tensor(0.4998, grad_fn=<MeanBackward1>) 51400
# tensor(0.4989, grad_fn=<MeanBackward1>) 51500
# tensor(0.5004, grad_fn=<MeanBackward1>) 51600
# tensor(0.4925, grad_fn=<MeanBackward1>) 51700
# tensor(0.4810, grad_fn=<MeanBackward1>) 51800
# tensor(0.4950, grad_fn=<MeanBackward1>) 51900
# tensor(0.4980, grad_fn=<MeanBackward1>) 52000
# tensor(0.4953, grad_fn=<MeanBackward1>) 52100
# tensor(0.5039, grad_fn=<MeanBackward1>) 52200
# tensor(0.5095, grad_fn=<MeanBackward1>) 52300
# tensor(0.5086, grad_fn=<MeanBackward1>) 52400
# tensor(0.4919, grad_fn=<MeanBackward1>) 52500
# tensor(0.5049, grad_fn=<MeanBackward1>) 52600
# tensor(0.4956, grad_fn=<MeanBackward1>) 52700
# tensor(0.4993, grad_fn=<MeanBackward1>) 52800
# tensor(0.4996, grad_fn=<MeanBackward1>) 52900
# tensor(0.4974, grad_fn=<MeanBackward1>) 53000
# tensor(0.5033, grad_fn=<MeanBackward1>) 53100
# tensor(0.5080, grad_fn=<MeanBackward1>) 53200
# tensor(0.4849, grad_fn=<MeanBackward1>) 53300
# tensor(0.4892, grad_fn=<MeanBackward1>) 53400
# tensor(0.5027, grad_fn=<MeanBackward1>) 53500
# tensor(0.5101, grad_fn=<MeanBackward1>) 53600
# tensor(0.5030, grad_fn=<MeanBackward1>) 53700
# tensor(0.5080, grad_fn=<MeanBackward1>) 53800
# tensor(0.4990, grad_fn=<MeanBackward1>) 53900
# tensor(0.4956, grad_fn=<MeanBackward1>) 54000
# tensor(0.5105, grad_fn=<MeanBackward1>) 54100
# tensor(0.4998, grad_fn=<MeanBackward1>) 54200
# tensor(0.4991, grad_fn=<MeanBackward1>) 54300
# tensor(0.5075, grad_fn=<MeanBackward1>) 54400
# tensor(0.5073, grad_fn=<MeanBackward1>) 54500
# tensor(0.5051, grad_fn=<MeanBackward1>) 54600
# tensor(0.5172, grad_fn=<MeanBackward1>) 54700
# tensor(0.5113, grad_fn=<MeanBackward1>) 54800
# tensor(0.4988, grad_fn=<MeanBackward1>) 54900
# tensor(0.4952, grad_fn=<MeanBackward1>) 55000
# tensor(0.5093, grad_fn=<MeanBackward1>) 55100
# tensor(0.4981, grad_fn=<MeanBackward1>) 55200
# tensor(0.5055, grad_fn=<MeanBackward1>) 55300
# tensor(0.5087, grad_fn=<MeanBackward1>) 55400
# tensor(0.4964, grad_fn=<MeanBackward1>) 55500
# tensor(0.4824, grad_fn=<MeanBackward1>) 55600
# tensor(0.5106, grad_fn=<MeanBackward1>) 55700
# tensor(0.5045, grad_fn=<MeanBackward1>) 55800
# tensor(0.4890, grad_fn=<MeanBackward1>) 55900
# tensor(0.5088, grad_fn=<MeanBackward1>) 56000
# tensor(0.4991, grad_fn=<MeanBackward1>) 56100
# tensor(0.4970, grad_fn=<MeanBackward1>) 56200
# tensor(0.5154, grad_fn=<MeanBackward1>) 56300
# tensor(0.4968, grad_fn=<MeanBackward1>) 56400
# tensor(0.5169, grad_fn=<MeanBackward1>) 56500
# tensor(0.4876, grad_fn=<MeanBackward1>) 56600
# tensor(0.5104, grad_fn=<MeanBackward1>) 56700
# tensor(0.5007, grad_fn=<MeanBackward1>) 56800
# tensor(0.4928, grad_fn=<MeanBackward1>) 56900
# tensor(0.4947, grad_fn=<MeanBackward1>) 57000
# tensor(0.4936, grad_fn=<MeanBackward1>) 57100
# tensor(0.5033, grad_fn=<MeanBackward1>) 57200
# tensor(0.4915, grad_fn=<MeanBackward1>) 57300
# tensor(0.5018, grad_fn=<MeanBackward1>) 57400
# tensor(0.5008, grad_fn=<MeanBackward1>) 57500
# tensor(0.4946, grad_fn=<MeanBackward1>) 57600
# tensor(0.4952, grad_fn=<MeanBackward1>) 57700
# tensor(0.5084, grad_fn=<MeanBackward1>) 57800
# tensor(0.5151, grad_fn=<MeanBackward1>) 57900
# tensor(0.4951, grad_fn=<MeanBackward1>) 58000
# tensor(0.5014, grad_fn=<MeanBackward1>) 58100
# tensor(0.5158, grad_fn=<MeanBackward1>) 58200
# tensor(0.5061, grad_fn=<MeanBackward1>) 58300
# tensor(0.5098, grad_fn=<MeanBackward1>) 58400
# tensor(0.4963, grad_fn=<MeanBackward1>) 58500
# tensor(0.4856, grad_fn=<MeanBackward1>) 58600
# tensor(0.4879, grad_fn=<MeanBackward1>) 58700
# tensor(0.5062, grad_fn=<MeanBackward1>) 58800
# tensor(0.4949, grad_fn=<MeanBackward1>) 58900
# tensor(0.4754, grad_fn=<MeanBackward1>) 59000
# tensor(0.5047, grad_fn=<MeanBackward1>) 59100
# tensor(0.4919, grad_fn=<MeanBackward1>) 59200
# tensor(0.4965, grad_fn=<MeanBackward1>) 59300
# tensor(0.5165, grad_fn=<MeanBackward1>) 59400
# tensor(0.5065, grad_fn=<MeanBackward1>) 59500
# tensor(0.4997, grad_fn=<MeanBackward1>) 59600
# tensor(0.4968, grad_fn=<MeanBackward1>) 59700
# tensor(0.5072, grad_fn=<MeanBackward1>) 59800
# tensor(0.4985, grad_fn=<MeanBackward1>) 59900
# tensor(0.5059, grad_fn=<MeanBackward1>) 60000
# tensor(0.4969, grad_fn=<MeanBackward1>) 60100
# tensor(0.4984, grad_fn=<MeanBackward1>) 60200
# tensor(0.5106, grad_fn=<MeanBackward1>) 60300
# tensor(0.4797, grad_fn=<MeanBackward1>) 60400
# tensor(0.4939, grad_fn=<MeanBackward1>) 60500
# tensor(0.5073, grad_fn=<MeanBackward1>) 60600
# tensor(0.5012, grad_fn=<MeanBackward1>) 60700
# tensor(0.5012, grad_fn=<MeanBackward1>) 60800
# tensor(0.5079, grad_fn=<MeanBackward1>) 60900
# tensor(0.4948, grad_fn=<MeanBackward1>) 61000
# tensor(0.4967, grad_fn=<MeanBackward1>) 61100
# tensor(0.4966, grad_fn=<MeanBackward1>) 61200
# tensor(0.5026, grad_fn=<MeanBackward1>) 61300
# tensor(0.4932, grad_fn=<MeanBackward1>) 61400
# tensor(0.5011, grad_fn=<MeanBackward1>) 61500
# tensor(0.4904, grad_fn=<MeanBackward1>) 61600
# tensor(0.4913, grad_fn=<MeanBackward1>) 61700
# tensor(0.5024, grad_fn=<MeanBackward1>) 61800
# tensor(0.5029, grad_fn=<MeanBackward1>) 61900
# tensor(0.4996, grad_fn=<MeanBackward1>) 62000
# tensor(0.4899, grad_fn=<MeanBackward1>) 62100
# tensor(0.5217, grad_fn=<MeanBackward1>) 62200
# tensor(0.5061, grad_fn=<MeanBackward1>) 62300
# tensor(0.4874, grad_fn=<MeanBackward1>) 62400
# tensor(0.5121, grad_fn=<MeanBackward1>) 62500
# tensor(0.4982, grad_fn=<MeanBackward1>) 62600
# tensor(0.5106, grad_fn=<MeanBackward1>) 62700
# tensor(0.4965, grad_fn=<MeanBackward1>) 62800
# tensor(0.4935, grad_fn=<MeanBackward1>) 62900
# tensor(0.5023, grad_fn=<MeanBackward1>) 63000
# tensor(0.4991, grad_fn=<MeanBackward1>) 63100
# tensor(0.5128, grad_fn=<MeanBackward1>) 63200
# tensor(0.4990, grad_fn=<MeanBackward1>) 63300
# tensor(0.5063, grad_fn=<MeanBackward1>) 63400
# tensor(0.4986, grad_fn=<MeanBackward1>) 63500
# tensor(0.5058, grad_fn=<MeanBackward1>) 63600
# tensor(0.4979, grad_fn=<MeanBackward1>) 63700
# tensor(0.4959, grad_fn=<MeanBackward1>) 63800
# tensor(0.4977, grad_fn=<MeanBackward1>) 63900
# tensor(0.4995, grad_fn=<MeanBackward1>) 64000
# tensor(0.5173, grad_fn=<MeanBackward1>) 64100
# tensor(0.5095, grad_fn=<MeanBackward1>) 64200
# tensor(0.5008, grad_fn=<MeanBackward1>) 64300
# tensor(0.4940, grad_fn=<MeanBackward1>) 64400
# tensor(0.4919, grad_fn=<MeanBackward1>) 64500
# tensor(0.5040, grad_fn=<MeanBackward1>) 64600
# tensor(0.5120, grad_fn=<MeanBackward1>) 64700
# tensor(0.5023, grad_fn=<MeanBackward1>) 64800
# tensor(0.4972, grad_fn=<MeanBackward1>) 64900
# tensor(0.5007, grad_fn=<MeanBackward1>) 65000
# tensor(0.5028, grad_fn=<MeanBackward1>) 65100
# tensor(0.4957, grad_fn=<MeanBackward1>) 65200
# tensor(0.4992, grad_fn=<MeanBackward1>) 65300
# tensor(0.5007, grad_fn=<MeanBackward1>) 65400
# tensor(0.4937, grad_fn=<MeanBackward1>) 65500
# tensor(0.5082, grad_fn=<MeanBackward1>) 65600
# tensor(0.5146, grad_fn=<MeanBackward1>) 65700
# tensor(0.4909, grad_fn=<MeanBackward1>) 65800
# tensor(0.5116, grad_fn=<MeanBackward1>) 65900
# tensor(0.5060, grad_fn=<MeanBackward1>) 66000
# tensor(0.4888, grad_fn=<MeanBackward1>) 66100
# tensor(0.4909, grad_fn=<MeanBackward1>) 66200
# tensor(0.5076, grad_fn=<MeanBackward1>) 66300
# tensor(0.4869, grad_fn=<MeanBackward1>) 66400
# tensor(0.5028, grad_fn=<MeanBackward1>) 66500
# tensor(0.5080, grad_fn=<MeanBackward1>) 66600
# tensor(0.4871, grad_fn=<MeanBackward1>) 66700
# tensor(0.5036, grad_fn=<MeanBackward1>) 66800
# tensor(0.4955, grad_fn=<MeanBackward1>) 66900
# tensor(0.4941, grad_fn=<MeanBackward1>) 67000
# tensor(0.5019, grad_fn=<MeanBackward1>) 67100
# tensor(0.5127, grad_fn=<MeanBackward1>) 67200
# tensor(0.4995, grad_fn=<MeanBackward1>) 67300
# tensor(0.4865, grad_fn=<MeanBackward1>) 67400
# tensor(0.4884, grad_fn=<MeanBackward1>) 67500
# tensor(0.5020, grad_fn=<MeanBackward1>) 67600
# tensor(0.4901, grad_fn=<MeanBackward1>) 67700
# tensor(0.5042, grad_fn=<MeanBackward1>) 67800
# tensor(0.4933, grad_fn=<MeanBackward1>) 67900
# tensor(0.4982, grad_fn=<MeanBackward1>) 68000
# tensor(0.5023, grad_fn=<MeanBackward1>) 68100
# tensor(0.5104, grad_fn=<MeanBackward1>) 68200
# tensor(0.5095, grad_fn=<MeanBackward1>) 68300
# tensor(0.5140, grad_fn=<MeanBackward1>) 68400
# tensor(0.5019, grad_fn=<MeanBackward1>) 68500
# tensor(0.5018, grad_fn=<MeanBackward1>) 68600
# tensor(0.4922, grad_fn=<MeanBackward1>) 68700
# tensor(0.5002, grad_fn=<MeanBackward1>) 68800
# tensor(0.5125, grad_fn=<MeanBackward1>) 68900
# tensor(0.4927, grad_fn=<MeanBackward1>) 69000
# tensor(0.4970, grad_fn=<MeanBackward1>) 69100
# tensor(0.4985, grad_fn=<MeanBackward1>) 69200
# tensor(0.5076, grad_fn=<MeanBackward1>) 69300
# tensor(0.5033, grad_fn=<MeanBackward1>) 69400
# tensor(0.4991, grad_fn=<MeanBackward1>) 69500
# tensor(0.4942, grad_fn=<MeanBackward1>) 69600
# tensor(0.5097, grad_fn=<MeanBackward1>) 69700
# tensor(0.4921, grad_fn=<MeanBackward1>) 69800
# tensor(0.5068, grad_fn=<MeanBackward1>) 69900
# tensor(0.4899, grad_fn=<MeanBackward1>) 70000
# tensor(0.5071, grad_fn=<MeanBackward1>) 70100
# tensor(0.5029, grad_fn=<MeanBackward1>) 70200
# tensor(0.5114, grad_fn=<MeanBackward1>) 70300
# tensor(0.4971, grad_fn=<MeanBackward1>) 70400
# tensor(0.5028, grad_fn=<MeanBackward1>) 70500
# tensor(0.4947, grad_fn=<MeanBackward1>) 70600
# tensor(0.5062, grad_fn=<MeanBackward1>) 70700
# tensor(0.4992, grad_fn=<MeanBackward1>) 70800
# tensor(0.5125, grad_fn=<MeanBackward1>) 70900
# tensor(0.5081, grad_fn=<MeanBackward1>) 71000
# tensor(0.5102, grad_fn=<MeanBackward1>) 71100
# tensor(0.5026, grad_fn=<MeanBackward1>) 71200
# tensor(0.4978, grad_fn=<MeanBackward1>) 71300
# tensor(0.4982, grad_fn=<MeanBackward1>) 71400
# tensor(0.4992, grad_fn=<MeanBackward1>) 71500
# tensor(0.5054, grad_fn=<MeanBackward1>) 71600
# tensor(0.4993, grad_fn=<MeanBackward1>) 71700
# tensor(0.5199, grad_fn=<MeanBackward1>) 71800
# tensor(0.5072, grad_fn=<MeanBackward1>) 71900
# tensor(0.5053, grad_fn=<MeanBackward1>) 72000
# tensor(0.5128, grad_fn=<MeanBackward1>) 72100
# tensor(0.4975, grad_fn=<MeanBackward1>) 72200
# tensor(0.4951, grad_fn=<MeanBackward1>) 72300
# tensor(0.4980, grad_fn=<MeanBackward1>) 72400
# tensor(0.5056, grad_fn=<MeanBackward1>) 72500
# tensor(0.5019, grad_fn=<MeanBackward1>) 72600
# tensor(0.5059, grad_fn=<MeanBackward1>) 72700
# tensor(0.4988, grad_fn=<MeanBackward1>) 72800
# tensor(0.4896, grad_fn=<MeanBackward1>) 72900
# tensor(0.5008, grad_fn=<MeanBackward1>) 73000
# tensor(0.5009, grad_fn=<MeanBackward1>) 73100
# tensor(0.4903, grad_fn=<MeanBackward1>) 73200
# tensor(0.5057, grad_fn=<MeanBackward1>) 73300
# tensor(0.5016, grad_fn=<MeanBackward1>) 73400
# tensor(0.5097, grad_fn=<MeanBackward1>) 73500
# tensor(0.4910, grad_fn=<MeanBackward1>) 73600
# tensor(0.5063, grad_fn=<MeanBackward1>) 73700
# tensor(0.5078, grad_fn=<MeanBackward1>) 73800
# tensor(0.4957, grad_fn=<MeanBackward1>) 73900
# tensor(0.5094, grad_fn=<MeanBackward1>) 74000
# tensor(0.5023, grad_fn=<MeanBackward1>) 74100
# tensor(0.4715, grad_fn=<MeanBackward1>) 74200
# tensor(0.4502, grad_fn=<MeanBackward1>) 74300
# tensor(0.4524, grad_fn=<MeanBackward1>) 74400
# tensor(0.4619, grad_fn=<MeanBackward1>) 74500
# tensor(0.4592, grad_fn=<MeanBackward1>) 74600
# tensor(0.4723, grad_fn=<MeanBackward1>) 74700
# tensor(0.4645, grad_fn=<MeanBackward1>) 74800
# tensor(0.4598, grad_fn=<MeanBackward1>) 74900
# tensor(0.4713, grad_fn=<MeanBackward1>) 75000
# tensor(0.4628, grad_fn=<MeanBackward1>) 75100
# tensor(0.4667, grad_fn=<MeanBackward1>) 75200
# tensor(0.4554, grad_fn=<MeanBackward1>) 75300
# tensor(0.4584, grad_fn=<MeanBackward1>) 75400
# tensor(0.4711, grad_fn=<MeanBackward1>) 75500
# tensor(0.4668, grad_fn=<MeanBackward1>) 75600
# tensor(0.4706, grad_fn=<MeanBackward1>) 75700
# tensor(0.4582, grad_fn=<MeanBackward1>) 75800
# tensor(0.4675, grad_fn=<MeanBackward1>) 75900
# tensor(0.4557, grad_fn=<MeanBackward1>) 76000
# tensor(0.4657, grad_fn=<MeanBackward1>) 76100
# tensor(0.4674, grad_fn=<MeanBackward1>) 76200
# tensor(0.4663, grad_fn=<MeanBackward1>) 76300
# tensor(0.4580, grad_fn=<MeanBackward1>) 76400
# tensor(0.4745, grad_fn=<MeanBackward1>) 76500
# tensor(0.4669, grad_fn=<MeanBackward1>) 76600
# tensor(0.4566, grad_fn=<MeanBackward1>) 76700
# tensor(0.4579, grad_fn=<MeanBackward1>) 76800
# tensor(0.4511, grad_fn=<MeanBackward1>) 76900
# tensor(0.4662, grad_fn=<MeanBackward1>) 77000
# tensor(0.4606, grad_fn=<MeanBackward1>) 77100
# tensor(0.4681, grad_fn=<MeanBackward1>) 77200
# tensor(0.4587, grad_fn=<MeanBackward1>) 77300
# tensor(0.4683, grad_fn=<MeanBackward1>) 77400
# tensor(0.4663, grad_fn=<MeanBackward1>) 77500
# tensor(0.4670, grad_fn=<MeanBackward1>) 77600
# tensor(0.4522, grad_fn=<MeanBackward1>) 77700
# tensor(0.4495, grad_fn=<MeanBackward1>) 77800
# tensor(0.4680, grad_fn=<MeanBackward1>) 77900
# tensor(0.4776, grad_fn=<MeanBackward1>) 78000
# tensor(0.4881, grad_fn=<MeanBackward1>) 78100
# tensor(0.4614, grad_fn=<MeanBackward1>) 78200
# tensor(0.4380, grad_fn=<MeanBackward1>) 78300
# tensor(0.4627, grad_fn=<MeanBackward1>) 78400
# tensor(0.4508, grad_fn=<MeanBackward1>) 78500
# tensor(0.4682, grad_fn=<MeanBackward1>) 78600
# tensor(0.4513, grad_fn=<MeanBackward1>) 78700
# tensor(0.4645, grad_fn=<MeanBackward1>) 78800
# tensor(0.4528, grad_fn=<MeanBackward1>) 78900
# tensor(0.4902, grad_fn=<MeanBackward1>) 79000
# tensor(0.5092, grad_fn=<MeanBackward1>) 79100
# tensor(0.4981, grad_fn=<MeanBackward1>) 79200
# tensor(0.4980, grad_fn=<MeanBackward1>) 79300
# tensor(0.4969, grad_fn=<MeanBackward1>) 79400
# tensor(0.4976, grad_fn=<MeanBackward1>) 79500
# tensor(0.5038, grad_fn=<MeanBackward1>) 79600
# tensor(0.4874, grad_fn=<MeanBackward1>) 79700
# tensor(0.5084, grad_fn=<MeanBackward1>) 79800
# tensor(0.5003, grad_fn=<MeanBackward1>) 79900
# tensor(0.4826, grad_fn=<MeanBackward1>) 80000
# tensor(0.5005, grad_fn=<MeanBackward1>) 80100
# tensor(0.4937, grad_fn=<MeanBackward1>) 80200
# tensor(0.4670, grad_fn=<MeanBackward1>) 80300
# tensor(0.5065, grad_fn=<MeanBackward1>) 80400
# tensor(0.4888, grad_fn=<MeanBackward1>) 80500
# tensor(0.4921, grad_fn=<MeanBackward1>) 80600
# tensor(0.5045, grad_fn=<MeanBackward1>) 80700
# tensor(0.4929, grad_fn=<MeanBackward1>) 80800
# tensor(0.4966, grad_fn=<MeanBackward1>) 80900
# tensor(0.5073, grad_fn=<MeanBackward1>) 81000
# tensor(0.4779, grad_fn=<MeanBackward1>) 81100
# tensor(0.5007, grad_fn=<MeanBackward1>) 81200
# tensor(0.5124, grad_fn=<MeanBackward1>) 81300
# tensor(0.4915, grad_fn=<MeanBackward1>) 81400
# tensor(0.5003, grad_fn=<MeanBackward1>) 81500
# tensor(0.4540, grad_fn=<MeanBackward1>) 81600
# tensor(0.4887, grad_fn=<MeanBackward1>) 81700
# tensor(0.4602, grad_fn=<MeanBackward1>) 81800
# tensor(0.4579, grad_fn=<MeanBackward1>) 81900
# tensor(0.4629, grad_fn=<MeanBackward1>) 82000
# tensor(0.4714, grad_fn=<MeanBackward1>) 82100
# tensor(0.4587, grad_fn=<MeanBackward1>) 82200
# tensor(0.4559, grad_fn=<MeanBackward1>) 82300
# tensor(0.4482, grad_fn=<MeanBackward1>) 82400
# tensor(0.4596, grad_fn=<MeanBackward1>) 82500
# tensor(0.4746, grad_fn=<MeanBackward1>) 82600
# tensor(0.4626, grad_fn=<MeanBackward1>) 82700
# tensor(0.4619, grad_fn=<MeanBackward1>) 82800
# tensor(0.4583, grad_fn=<MeanBackward1>) 82900
# tensor(0.4579, grad_fn=<MeanBackward1>) 83000
# tensor(0.4568, grad_fn=<MeanBackward1>) 83100
# tensor(0.4533, grad_fn=<MeanBackward1>) 83200
# tensor(0.4692, grad_fn=<MeanBackward1>) 83300
# tensor(0.4620, grad_fn=<MeanBackward1>) 83400
# tensor(0.4602, grad_fn=<MeanBackward1>) 83500
# tensor(0.4790, grad_fn=<MeanBackward1>) 83600
# tensor(0.4488, grad_fn=<MeanBackward1>) 83700
# tensor(0.4587, grad_fn=<MeanBackward1>) 83800
# tensor(0.4506, grad_fn=<MeanBackward1>) 83900
# tensor(0.4724, grad_fn=<MeanBackward1>) 84000
# tensor(0.4555, grad_fn=<MeanBackward1>) 84100
# tensor(0.4648, grad_fn=<MeanBackward1>) 84200
# tensor(0.4888, grad_fn=<MeanBackward1>) 84300
# tensor(0.4424, grad_fn=<MeanBackward1>) 84400
# tensor(0.4491, grad_fn=<MeanBackward1>) 84500
# tensor(0.4722, grad_fn=<MeanBackward1>) 84600
# tensor(0.4397, grad_fn=<MeanBackward1>) 84700
# tensor(0.4536, grad_fn=<MeanBackward1>) 84800
# tensor(0.4952, grad_fn=<MeanBackward1>) 84900
# tensor(0.4641, grad_fn=<MeanBackward1>) 85000
# tensor(0.4774, grad_fn=<MeanBackward1>) 85100
# tensor(0.4443, grad_fn=<MeanBackward1>) 85200
# tensor(0.4514, grad_fn=<MeanBackward1>) 85300
# tensor(0.4933, grad_fn=<MeanBackward1>) 85400
# tensor(0.4573, grad_fn=<MeanBackward1>) 85500
# tensor(0.4510, grad_fn=<MeanBackward1>) 85600
# tensor(0.4555, grad_fn=<MeanBackward1>) 85700
# tensor(0.4545, grad_fn=<MeanBackward1>) 85800
# tensor(0.4877, grad_fn=<MeanBackward1>) 85900
# tensor(0.4671, grad_fn=<MeanBackward1>) 86000
# tensor(0.4596, grad_fn=<MeanBackward1>) 86100
# tensor(0.4728, grad_fn=<MeanBackward1>) 86200
# tensor(0.4501, grad_fn=<MeanBackward1>) 86300
# tensor(0.4517, grad_fn=<MeanBackward1>) 86400
# tensor(0.4688, grad_fn=<MeanBackward1>) 86500
# tensor(0.4578, grad_fn=<MeanBackward1>) 86600
# tensor(0.4573, grad_fn=<MeanBackward1>) 86700
# tensor(0.4540, grad_fn=<MeanBackward1>) 86800
# tensor(0.4490, grad_fn=<MeanBackward1>) 86900
# tensor(0.4691, grad_fn=<MeanBackward1>) 87000
# tensor(0.4814, grad_fn=<MeanBackward1>) 87100
# tensor(0.4486, grad_fn=<MeanBackward1>) 87200
# tensor(0.4636, grad_fn=<MeanBackward1>) 87300
# tensor(0.5081, grad_fn=<MeanBackward1>) 87400
# tensor(0.4924, grad_fn=<MeanBackward1>) 87500
# tensor(0.4836, grad_fn=<MeanBackward1>) 87600
# tensor(0.5199, grad_fn=<MeanBackward1>) 87700
# tensor(0.4986, grad_fn=<MeanBackward1>) 87800
# tensor(0.4811, grad_fn=<MeanBackward1>) 87900
# tensor(0.4986, grad_fn=<MeanBackward1>) 88000
# tensor(0.4975, grad_fn=<MeanBackward1>) 88100
# tensor(0.5038, grad_fn=<MeanBackward1>) 88200
# tensor(0.4956, grad_fn=<MeanBackward1>) 88300
# tensor(0.5030, grad_fn=<MeanBackward1>) 88400
# tensor(0.5030, grad_fn=<MeanBackward1>) 88500
# tensor(0.5007, grad_fn=<MeanBackward1>) 88600
# tensor(0.4950, grad_fn=<MeanBackward1>) 88700
# tensor(0.4989, grad_fn=<MeanBackward1>) 88800
# tensor(0.5124, grad_fn=<MeanBackward1>) 88900
# tensor(0.5094, grad_fn=<MeanBackward1>) 89000
# tensor(0.4855, grad_fn=<MeanBackward1>) 89100
# tensor(0.4789, grad_fn=<MeanBackward1>) 89200
# tensor(0.5007, grad_fn=<MeanBackward1>) 89300
# tensor(0.5047, grad_fn=<MeanBackward1>) 89400
# tensor(0.5117, grad_fn=<MeanBackward1>) 89500
# tensor(0.4906, grad_fn=<MeanBackward1>) 89600
# tensor(0.4882, grad_fn=<MeanBackward1>) 89700
# tensor(0.5121, grad_fn=<MeanBackward1>) 89800
# tensor(0.4973, grad_fn=<MeanBackward1>) 89900
# tensor(0.4972, grad_fn=<MeanBackward1>) 90000
# tensor(0.5082, grad_fn=<MeanBackward1>) 90100
# tensor(0.5003, grad_fn=<MeanBackward1>) 90200
# tensor(0.5121, grad_fn=<MeanBackward1>) 90300
# tensor(0.5087, grad_fn=<MeanBackward1>) 90400
# tensor(0.4919, grad_fn=<MeanBackward1>) 90500
# tensor(0.4831, grad_fn=<MeanBackward1>) 90600
# tensor(0.4957, grad_fn=<MeanBackward1>) 90700
# tensor(0.4883, grad_fn=<MeanBackward1>) 90800
# tensor(0.5213, grad_fn=<MeanBackward1>) 90900
# tensor(0.5005, grad_fn=<MeanBackward1>) 91000
# tensor(0.5054, grad_fn=<MeanBackward1>) 91100
# tensor(0.5067, grad_fn=<MeanBackward1>) 91200
# tensor(0.4703, grad_fn=<MeanBackward1>) 91300
# tensor(0.4382, grad_fn=<MeanBackward1>) 91400
# tensor(0.4545, grad_fn=<MeanBackward1>) 91500
# tensor(0.4708, grad_fn=<MeanBackward1>) 91600
# tensor(0.4724, grad_fn=<MeanBackward1>) 91700
# tensor(0.4654, grad_fn=<MeanBackward1>) 91800
# tensor(0.4718, grad_fn=<MeanBackward1>) 91900
# tensor(0.4594, grad_fn=<MeanBackward1>) 92000
# tensor(0.4614, grad_fn=<MeanBackward1>) 92100
# tensor(0.4804, grad_fn=<MeanBackward1>) 92200
# tensor(0.4711, grad_fn=<MeanBackward1>) 92300
# tensor(0.4706, grad_fn=<MeanBackward1>) 92400
# tensor(0.4724, grad_fn=<MeanBackward1>) 92500
# tensor(0.4629, grad_fn=<MeanBackward1>) 92600
# tensor(0.4544, grad_fn=<MeanBackward1>) 92700
# tensor(0.4696, grad_fn=<MeanBackward1>) 92800
# tensor(0.4542, grad_fn=<MeanBackward1>) 92900
# tensor(0.4598, grad_fn=<MeanBackward1>) 93000
# tensor(0.4681, grad_fn=<MeanBackward1>) 93100
# tensor(0.4601, grad_fn=<MeanBackward1>) 93200
# tensor(0.4685, grad_fn=<MeanBackward1>) 93300
# tensor(0.4737, grad_fn=<MeanBackward1>) 93400
# tensor(0.4592, grad_fn=<MeanBackward1>) 93500
# tensor(0.5144, grad_fn=<MeanBackward1>) 93600
# tensor(0.5045, grad_fn=<MeanBackward1>) 93700
# tensor(0.5110, grad_fn=<MeanBackward1>) 93800
# tensor(0.4944, grad_fn=<MeanBackward1>) 93900
# tensor(0.4941, grad_fn=<MeanBackward1>) 94000
# tensor(0.4992, grad_fn=<MeanBackward1>) 94100
# tensor(0.4862, grad_fn=<MeanBackward1>) 94200
# tensor(0.4938, grad_fn=<MeanBackward1>) 94300
# tensor(0.4888, grad_fn=<MeanBackward1>) 94400
# tensor(0.4933, grad_fn=<MeanBackward1>) 94500
# tensor(0.4879, grad_fn=<MeanBackward1>) 94600
# tensor(0.5079, grad_fn=<MeanBackward1>) 94700
# tensor(0.4876, grad_fn=<MeanBackward1>) 94800
# tensor(0.4996, grad_fn=<MeanBackward1>) 94900
# tensor(0.5094, grad_fn=<MeanBackward1>) 95000
# tensor(0.5047, grad_fn=<MeanBackward1>) 95100
# tensor(0.4767, grad_fn=<MeanBackward1>) 95200
# tensor(0.5059, grad_fn=<MeanBackward1>) 95300
# tensor(0.5072, grad_fn=<MeanBackward1>) 95400
# tensor(0.5069, grad_fn=<MeanBackward1>) 95500
# tensor(0.4955, grad_fn=<MeanBackward1>) 95600
# tensor(0.4980, grad_fn=<MeanBackward1>) 95700
# tensor(0.5024, grad_fn=<MeanBackward1>) 95800
# tensor(0.4990, grad_fn=<MeanBackward1>) 95900
# tensor(0.4993, grad_fn=<MeanBackward1>) 96000
# tensor(0.4930, grad_fn=<MeanBackward1>) 96100
# tensor(0.5050, grad_fn=<MeanBackward1>) 96200
# tensor(0.5040, grad_fn=<MeanBackward1>) 96300
# tensor(0.4902, grad_fn=<MeanBackward1>) 96400
# tensor(0.4902, grad_fn=<MeanBackward1>) 96500
# tensor(0.4975, grad_fn=<MeanBackward1>) 96600
# tensor(0.4844, grad_fn=<MeanBackward1>) 96700
# tensor(0.5104, grad_fn=<MeanBackward1>) 96800
# tensor(0.4901, grad_fn=<MeanBackward1>) 96900
# tensor(0.4907, grad_fn=<MeanBackward1>) 97000
# tensor(0.5056, grad_fn=<MeanBackward1>) 97100
# tensor(0.4881, grad_fn=<MeanBackward1>) 97200
# tensor(0.5057, grad_fn=<MeanBackward1>) 97300
# tensor(0.5024, grad_fn=<MeanBackward1>) 97400
# tensor(0.4946, grad_fn=<MeanBackward1>) 97500
# tensor(0.5117, grad_fn=<MeanBackward1>) 97600
# tensor(0.5052, grad_fn=<MeanBackward1>) 97700
# tensor(0.5040, grad_fn=<MeanBackward1>) 97800
# tensor(0.5098, grad_fn=<MeanBackward1>) 97900
# tensor(0.4945, grad_fn=<MeanBackward1>) 98000
# tensor(0.5096, grad_fn=<MeanBackward1>) 98100
# tensor(0.5033, grad_fn=<MeanBackward1>) 98200
# tensor(0.5094, grad_fn=<MeanBackward1>) 98300
# tensor(0.4894, grad_fn=<MeanBackward1>) 98400
# tensor(0.4988, grad_fn=<MeanBackward1>) 98500
# tensor(0.5049, grad_fn=<MeanBackward1>) 98600
# tensor(0.5032, grad_fn=<MeanBackward1>) 98700
# tensor(0.4974, grad_fn=<MeanBackward1>) 98800
# tensor(0.5156, grad_fn=<MeanBackward1>) 98900
# tensor(0.5017, grad_fn=<MeanBackward1>) 99000
# tensor(0.4994, grad_fn=<MeanBackward1>) 99100
# tensor(0.5020, grad_fn=<MeanBackward1>) 99200
# tensor(0.4978, grad_fn=<MeanBackward1>) 99300
# tensor(0.5073, grad_fn=<MeanBackward1>) 99400
# tensor(0.5072, grad_fn=<MeanBackward1>) 99500
# tensor(0.4957, grad_fn=<MeanBackward1>) 99600
# tensor(0.4946, grad_fn=<MeanBackward1>) 99700
# tensor(0.5079, grad_fn=<MeanBackward1>) 99800
# tensor(0.5127, grad_fn=<MeanBackward1>) 99900

# %% [markdown]
# SDE simulation functions

# %%
# This is the solving the VE process exactly given deterministic initial conditions
def ve_dynamics(init, sigma_min, sigma_max, T=1.0):
    init = init + sigma_max * torch.randn_like(init)
    return init
    
def reverse_sde(score, init, sigma_min, sigma_max, T=1.0, lr=0.01):
    step = int(T/lr)
    for i in range(step,-1,-1):
        evalpoint = torch.cat(((torch.tensor(lr*i/T)).repeat(init.shape[0],1),init),1)
        drift = torch.zeros_like(evalpoint)
        sigma = sigma_min *(sigma_max/sigma_min)**(i*lr/T)
        diffusion = sigma * torch.sqrt(2*(torch.log(sigma_max)-torch.log(sigma_min)))
        
        init = init + lr  * diffusion**2 * score(evalpoint).detach() 
        init = init + diffusion * torch.randn_like(init) * np.sqrt(lr)
    return init



# The following is the deterministic ODE flow that can also sample from the target distribution

def reverse_ode_flow(score,init, sigma_min, sigma_max, T=1.0, lr = 0.01):
    step = int(T/lr)
    for i in range(step,-1,-1):
        evalpoint = torch.cat(((torch.tensor(lr*i/T)).repeat(init.shape[0],1),init),1)
        sigma = sigma_min *(sigma_max/sigma_min)**(i*lr/T)
        diffusion = sigma * torch.sqrt(2*(torch.log(sigma_max)-torch.log(sigma_min)))
        
        init = init + lr/2* diffusion**2 * score(evalpoint).detach() 
    return init

# %% [markdown]
# Sample using the score network

# %%
# Denoising the normal distribution 
samples_lang = torch.randn(10000, 1)*sigma_max # * (right_bound - left_bound) + left_bound
samples_lang = reverse_sde(scorenet, samples_lang, torch.tensor(sigma_min), torch.tensor(sigma_max)).detach().numpy()

# %%
#plt.clf()
p_samples = toy_data.inf_train_gen(dataset, batch_size = 7160)
ve_samples = ve_dynamics(torch.tensor(p_samples).to(dtype = torch.float32),  torch.tensor(sigma_min), torch.tensor(sigma_max))
# Out:
# "\nbinsize=500\nplt.hist(ve_samples, label='generated', alpha=0.9,cumulative=-1, density=True, bins=binsize)\nplt.hist(p_samples, label='true',alpha=0.5,cumulative=-1, density=True, bins=binsize)\nplt.axis('square')\nplt.title('Samples from VE process')\nplt.legend()\nplt.show()\n"

# %%
filename = f"../../assets/{dataset}/ve_sgm_{N_samples}samples.pickle"
with open(filename,"wb") as fw:
    pickle.dump([ve_samples, samples_lang] , fw)
