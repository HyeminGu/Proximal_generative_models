# %% [markdown]
# # Score-based Generative Modeling with SDEs (Simple examples)

# %%
import os

# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import torch.nn as nn
import lib.toy_data as toy_data
import numpy as np
import pickle

# %% [markdown]
# Basic parameters

# %%
learning_rate = 1e-3 # learning rate for training neural network
batch_size = 10000  # batch size during training of neural network
N_samples = 10000
epochs = 100000   # Number of training epochs for the neural network
sigma_max = 100.0 # 100 for df=1.0
sigma_min = 0.01  # 0.01 for df=1.0
T = 5    # Forward simulation time in the forward SDE (fixed)
dataset = 'Heavytail_submanifold' # Dataset choice, see toy_data for full options of toy datasets
d = 10
d_orth=100

# %% [markdown]
# We first initialize the neural net that models the score function.

# %%
## Model construction

class DenoisingModel(nn.Module):
    
    def __init__(self, hidden_units=128):
        super(DenoisingModel, self).__init__()
        # hidden_units = 32
        
        # data and timestep
        self.fc1 = nn.Linear(d+d_orth+1, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc1.weight)
        self.activation1 = nn.GELU()
        self.fc2 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc2.weight)
        self.activation2 = nn.GELU()
        self.fc3 = nn.Linear(int(hidden_units), d+d_orth+1, bias=True)
        nn.init.xavier_uniform_(self.fc3.weight)
        self.activation3 = nn.GELU()
        
        self.fc4 = nn.Linear(d+d_orth+1, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc4.weight)
        self.activation4 = nn.GELU()
        self.fc5 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc5.weight)
        self.activation5 = nn.GELU()
        self.fc6 = nn.Linear(int(hidden_units), d+d_orth+1, bias=True)
        nn.init.xavier_uniform_(self.fc6.weight)
        self.activation6 = nn.GELU()
        
        self.fc7 = nn.Linear(d+d_orth+1, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc7.weight)
        self.activation7 = nn.GELU()
        self.fc8 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc8.weight)
        self.activation8 = nn.GELU()
        self.fc9 = nn.Linear(int(hidden_units), d+d_orth, bias=True)
        nn.init.xavier_uniform_(self.fc9.weight)
        
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.activation1(x)
        x = self.fc2(x)
        x = self.activation2(x)
        x = self.fc3(x)
        x = self.activation3(x)
        x = self.fc4(x)
        x = self.activation4(x)
        x = self.fc5(x)
        x = self.activation5(x)
        x = self.fc6(x)
        x = self.activation6(x)
        x = self.fc7(x)
        x = self.activation7(x)
        x = self.fc8(x)
        x = self.activation8(x)
        x = self.fc9(x)
        
        return x
      
scorenet = DenoisingModel()
print(scorenet)
optimizer = optim.Adam(scorenet.parameters(), lr=learning_rate)
# Out:
# DenoisingModel(
#   (fc1): Linear(in_features=111, out_features=256, bias=True)
#   (activation1): GELU(approximate='none')
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (activation2): GELU(approximate='none')
#   (fc3): Linear(in_features=256, out_features=111, bias=True)
#   (activation3): GELU(approximate='none')
#   (fc4): Linear(in_features=111, out_features=256, bias=True)
#   (activation4): GELU(approximate='none')
#   (fc5): Linear(in_features=256, out_features=256, bias=True)
#   (activation5): GELU(approximate='none')
#   (fc6): Linear(in_features=256, out_features=111, bias=True)
#   (activation6): GELU(approximate='none')
#   (fc7): Linear(in_features=111, out_features=256, bias=True)
#   (activation7): GELU(approximate='none')
#   (fc8): Linear(in_features=256, out_features=256, bias=True)
#   (activation8): GELU(approximate='none')
#   (fc9): Linear(in_features=256, out_features=110, bias=True)
# )

# %% [markdown]
# Define loss functions. These loss functions assume that the forward process is a variance exploding process $dx =  + \sigma_t dW$. The choice of $\lambda(t)$ in the SGM objective function is equal to 1 (the constant in front of the dW term).

# %%
# Loss function -- we use the denoising diffusions objective function
# Scorenet is the score model, samples are the training samples, Tmin/Tmax are the time interval that is being trained on, and eps is so that Tmin is not sampled. 

def time_dsm_score_estimator(scorenet,samples,sigma_min,sigma_max,Tmin,Tmax,eps):

    t = torch.rand(samples.shape[0]) * (Tmax - Tmin - eps) + eps + Tmin # sample uniformly from time interval

    # Add noise to the training samples
    z = torch.randn_like(samples)
    sigmas = sigma_min * (sigma_max/sigma_min)**((t - Tmin)/(Tmax - Tmin))
    sigmas = sigmas.view(samples.shape[0],*([1]*len(samples.shape[1:])))
    noise = z * sigmas
    #tenlarge = t.repeat(2,1).T
    perturbed_samples = samples + noise

    # Evaluate score and marginal score on the perturbed samples
    #target = - 1/ (sigmas ** 2) * (noise)
    score_eval_samples = torch.cat((t.reshape(-1,1),perturbed_samples),1)
    scores = scorenet(score_eval_samples)

    # Evaluate the loss function 
    #target = target.view(target.shape[0],-1)
    scores = scores.view(scores.shape[0],-1)
    loss = 0.5 * ((scores * sigmas + z) ** 2).sum(dim = -1) 

    return loss.mean(dim = 0)


# Loss function
# This is for if you have a specific mesh for the time interval you would like the network to train on. 
def deterministic_time_dsm_score_estimator(scorenet,samples,t):

    loss = 0
    for ii in range(len(t)-1):

        # Add noise to the training samples
        sigmas = torch.sqrt(1 - torch.exp(-t[ii]))
        noise = torch.randn_like(samples) * sigmas
        perturbed_samples = samples * torch.exp(-0.5 * t[ii]) + noise

        # Evaluate score and marginal score on perturbed samples
        target = - 1/ (sigmas ** 2) * (noise)
        score_eval_samples = torch.cat((t[ii].repeat(perturbed_samples.shape[0],1),perturbed_samples),1)
        scores = scorenet(score_eval_samples)

        # Evaluate loss function at this particular t[ii]
        target = target.view(target.shape[0],-1)
        scores = scores.view(scores.shape[0],-1)
        loss_vec = 0.5 * ((scores-target) ** 2).sum(dim = -1) 
        loss = loss + (t[ii+1]-t[ii])*loss_vec.mean(dim = 0)

    return loss

# %% [markdown]
# Training the score network

# %%
# Training the score network
# sample toy_data
#p_samples_all = toy_data.inf_train_gen(dataset, N_samples)
p_samples = toy_data.inf_train_gen(dataset, N_samples)

for step in range(epochs):
    #for i in range(int(N_samples//batch_size)):
    #    p_samples = p_samples_all[i*batch_size:(i+1)*batch_size,:]
    samples = torch.tensor(p_samples).to(dtype = torch.float32)

    # evaluate loss function and gradient
    loss = time_dsm_score_estimator(scorenet,samples,sigma_min, sigma_max, 0,T,eps = 0.0005)
    optimizer.zero_grad()
    loss.backward()

    # Update score network
    optimizer.step()

    if not step%100:
        print(loss,step)
# Out:
# tensor(1.7372e+10, grad_fn=<MeanBackward1>) 0
# tensor(113.7866, grad_fn=<MeanBackward1>) 100
# tensor(57.8126, grad_fn=<MeanBackward1>) 200
# tensor(55.4715, grad_fn=<MeanBackward1>) 300
# tensor(55.3222, grad_fn=<MeanBackward1>) 400
# tensor(55.1756, grad_fn=<MeanBackward1>) 500
# tensor(55.1019, grad_fn=<MeanBackward1>) 600
# tensor(54.9758, grad_fn=<MeanBackward1>) 700
# tensor(55.0227, grad_fn=<MeanBackward1>) 800
# tensor(55.0504, grad_fn=<MeanBackward1>) 900
# tensor(55.0073, grad_fn=<MeanBackward1>) 1000
# tensor(55.0374, grad_fn=<MeanBackward1>) 1100
# tensor(55.0821, grad_fn=<MeanBackward1>) 1200
# tensor(55.0198, grad_fn=<MeanBackward1>) 1300
# tensor(55.1877, grad_fn=<MeanBackward1>) 1400
# tensor(54.9707, grad_fn=<MeanBackward1>) 1500
# tensor(54.9946, grad_fn=<MeanBackward1>) 1600
# tensor(55.0662, grad_fn=<MeanBackward1>) 1700
# tensor(54.8866, grad_fn=<MeanBackward1>) 1800
# tensor(54.9048, grad_fn=<MeanBackward1>) 1900
# tensor(54.9530, grad_fn=<MeanBackward1>) 2000
# tensor(54.9644, grad_fn=<MeanBackward1>) 2100
# tensor(55.0466, grad_fn=<MeanBackward1>) 2200
# tensor(54.9935, grad_fn=<MeanBackward1>) 2300
# tensor(55.0812, grad_fn=<MeanBackward1>) 2400
# tensor(54.8576, grad_fn=<MeanBackward1>) 2500
# tensor(54.9815, grad_fn=<MeanBackward1>) 2600
# tensor(54.7927, grad_fn=<MeanBackward1>) 2700
# tensor(55.1122, grad_fn=<MeanBackward1>) 2800
# tensor(55.1360, grad_fn=<MeanBackward1>) 2900
# tensor(55.0034, grad_fn=<MeanBackward1>) 3000
# tensor(54.9763, grad_fn=<MeanBackward1>) 3100
# tensor(55.0868, grad_fn=<MeanBackward1>) 3200
# tensor(54.9786, grad_fn=<MeanBackward1>) 3300
# tensor(54.9265, grad_fn=<MeanBackward1>) 3400
# tensor(54.9383, grad_fn=<MeanBackward1>) 3500
# tensor(55.0555, grad_fn=<MeanBackward1>) 3600
# tensor(54.8926, grad_fn=<MeanBackward1>) 3700
# tensor(54.9734, grad_fn=<MeanBackward1>) 3800
# tensor(54.9355, grad_fn=<MeanBackward1>) 3900
# tensor(55.0640, grad_fn=<MeanBackward1>) 4000
# tensor(55.0465, grad_fn=<MeanBackward1>) 4100
# tensor(55.0117, grad_fn=<MeanBackward1>) 4200
# tensor(55.0454, grad_fn=<MeanBackward1>) 4300
# tensor(54.9492, grad_fn=<MeanBackward1>) 4400
# tensor(54.9990, grad_fn=<MeanBackward1>) 4500
# tensor(54.9957, grad_fn=<MeanBackward1>) 4600
# tensor(54.9969, grad_fn=<MeanBackward1>) 4700
# tensor(54.9864, grad_fn=<MeanBackward1>) 4800
# tensor(54.9420, grad_fn=<MeanBackward1>) 4900
# tensor(54.9928, grad_fn=<MeanBackward1>) 5000
# tensor(54.9528, grad_fn=<MeanBackward1>) 5100
# tensor(55.0913, grad_fn=<MeanBackward1>) 5200
# tensor(54.9289, grad_fn=<MeanBackward1>) 5300
# tensor(54.8292, grad_fn=<MeanBackward1>) 5400
# tensor(54.8882, grad_fn=<MeanBackward1>) 5500
# tensor(54.8354, grad_fn=<MeanBackward1>) 5600
# tensor(54.9640, grad_fn=<MeanBackward1>) 5700
# tensor(54.9766, grad_fn=<MeanBackward1>) 5800
# tensor(55.3953, grad_fn=<MeanBackward1>) 5900
# tensor(55.0422, grad_fn=<MeanBackward1>) 6000
# tensor(54.8980, grad_fn=<MeanBackward1>) 6100
# tensor(54.9737, grad_fn=<MeanBackward1>) 6200
# tensor(54.9085, grad_fn=<MeanBackward1>) 6300
# tensor(54.9458, grad_fn=<MeanBackward1>) 6400
# tensor(54.9810, grad_fn=<MeanBackward1>) 6500
# tensor(55.1257, grad_fn=<MeanBackward1>) 6600
# tensor(54.9470, grad_fn=<MeanBackward1>) 6700
# tensor(54.9280, grad_fn=<MeanBackward1>) 6800
# tensor(54.9331, grad_fn=<MeanBackward1>) 6900
# tensor(54.9261, grad_fn=<MeanBackward1>) 7000
# tensor(54.8759, grad_fn=<MeanBackward1>) 7100
# tensor(54.9042, grad_fn=<MeanBackward1>) 7200
# tensor(54.9925, grad_fn=<MeanBackward1>) 7300
# tensor(54.9596, grad_fn=<MeanBackward1>) 7400
# tensor(54.9418, grad_fn=<MeanBackward1>) 7500
# tensor(54.9540, grad_fn=<MeanBackward1>) 7600
# tensor(54.8657, grad_fn=<MeanBackward1>) 7700
# tensor(54.8645, grad_fn=<MeanBackward1>) 7800
# tensor(54.8206, grad_fn=<MeanBackward1>) 7900
# tensor(54.7234, grad_fn=<MeanBackward1>) 8000
# tensor(54.8155, grad_fn=<MeanBackward1>) 8100
# tensor(54.8936, grad_fn=<MeanBackward1>) 8200
# tensor(54.8438, grad_fn=<MeanBackward1>) 8300
# tensor(54.6851, grad_fn=<MeanBackward1>) 8400
# tensor(54.8478, grad_fn=<MeanBackward1>) 8500
# tensor(54.7730, grad_fn=<MeanBackward1>) 8600
# tensor(54.7410, grad_fn=<MeanBackward1>) 8700
# tensor(54.6683, grad_fn=<MeanBackward1>) 8800
# tensor(54.7301, grad_fn=<MeanBackward1>) 8900
# tensor(54.7684, grad_fn=<MeanBackward1>) 9000
# tensor(54.7464, grad_fn=<MeanBackward1>) 9100
# tensor(54.7044, grad_fn=<MeanBackward1>) 9200
# tensor(54.6094, grad_fn=<MeanBackward1>) 9300
# tensor(54.7155, grad_fn=<MeanBackward1>) 9400
# tensor(54.5254, grad_fn=<MeanBackward1>) 9500
# tensor(54.4994, grad_fn=<MeanBackward1>) 9600
# tensor(54.5445, grad_fn=<MeanBackward1>) 9700
# tensor(54.5879, grad_fn=<MeanBackward1>) 9800
# tensor(54.5162, grad_fn=<MeanBackward1>) 9900
# tensor(54.5975, grad_fn=<MeanBackward1>) 10000
# tensor(54.4915, grad_fn=<MeanBackward1>) 10100
# tensor(54.5135, grad_fn=<MeanBackward1>) 10200
# tensor(54.4862, grad_fn=<MeanBackward1>) 10300
# tensor(54.4124, grad_fn=<MeanBackward1>) 10400
# tensor(54.5103, grad_fn=<MeanBackward1>) 10500
# tensor(54.4639, grad_fn=<MeanBackward1>) 10600
# tensor(54.4509, grad_fn=<MeanBackward1>) 10700
# tensor(54.3836, grad_fn=<MeanBackward1>) 10800
# tensor(54.2449, grad_fn=<MeanBackward1>) 10900
# tensor(54.3141, grad_fn=<MeanBackward1>) 11000
# tensor(54.1319, grad_fn=<MeanBackward1>) 11100
# tensor(54.3155, grad_fn=<MeanBackward1>) 11200
# tensor(54.2178, grad_fn=<MeanBackward1>) 11300
# tensor(54.3495, grad_fn=<MeanBackward1>) 11400
# tensor(54.4199, grad_fn=<MeanBackward1>) 11500
# tensor(54.3036, grad_fn=<MeanBackward1>) 11600
# tensor(54.0600, grad_fn=<MeanBackward1>) 11700
# tensor(54.1474, grad_fn=<MeanBackward1>) 11800
# tensor(54.0683, grad_fn=<MeanBackward1>) 11900
# tensor(53.9608, grad_fn=<MeanBackward1>) 12000
# tensor(53.8343, grad_fn=<MeanBackward1>) 12100
# tensor(53.9770, grad_fn=<MeanBackward1>) 12200
# tensor(54.1053, grad_fn=<MeanBackward1>) 12300
# tensor(53.7642, grad_fn=<MeanBackward1>) 12400
# tensor(53.9505, grad_fn=<MeanBackward1>) 12500
# tensor(53.9134, grad_fn=<MeanBackward1>) 12600
# tensor(53.6694, grad_fn=<MeanBackward1>) 12700
# tensor(53.7672, grad_fn=<MeanBackward1>) 12800
# tensor(53.6274, grad_fn=<MeanBackward1>) 12900
# tensor(53.6850, grad_fn=<MeanBackward1>) 13000
# tensor(53.5600, grad_fn=<MeanBackward1>) 13100
# tensor(53.6212, grad_fn=<MeanBackward1>) 13200
# tensor(53.5458, grad_fn=<MeanBackward1>) 13300
# tensor(53.4984, grad_fn=<MeanBackward1>) 13400
# tensor(53.4638, grad_fn=<MeanBackward1>) 13500
# tensor(53.3133, grad_fn=<MeanBackward1>) 13600
# tensor(53.2564, grad_fn=<MeanBackward1>) 13700
# tensor(53.3549, grad_fn=<MeanBackward1>) 13800
# tensor(53.4328, grad_fn=<MeanBackward1>) 13900
# tensor(53.1726, grad_fn=<MeanBackward1>) 14000
# tensor(53.0279, grad_fn=<MeanBackward1>) 14100
# tensor(53.2147, grad_fn=<MeanBackward1>) 14200
# tensor(53.0132, grad_fn=<MeanBackward1>) 14300
# tensor(53.5543, grad_fn=<MeanBackward1>) 14400
# tensor(53.0685, grad_fn=<MeanBackward1>) 14500
# tensor(53.1100, grad_fn=<MeanBackward1>) 14600
# tensor(52.8200, grad_fn=<MeanBackward1>) 14700
# tensor(52.9679, grad_fn=<MeanBackward1>) 14800
# tensor(52.8509, grad_fn=<MeanBackward1>) 14900
# tensor(52.7242, grad_fn=<MeanBackward1>) 15000
# tensor(52.5128, grad_fn=<MeanBackward1>) 15100
# tensor(52.8279, grad_fn=<MeanBackward1>) 15200
# tensor(52.2601, grad_fn=<MeanBackward1>) 15300
# tensor(52.3773, grad_fn=<MeanBackward1>) 15400
# tensor(52.4130, grad_fn=<MeanBackward1>) 15500
# tensor(52.1915, grad_fn=<MeanBackward1>) 15600
# tensor(51.9729, grad_fn=<MeanBackward1>) 15700
# tensor(51.9834, grad_fn=<MeanBackward1>) 15800
# tensor(52.0607, grad_fn=<MeanBackward1>) 15900
# tensor(51.9149, grad_fn=<MeanBackward1>) 16000
# tensor(51.8330, grad_fn=<MeanBackward1>) 16100
# tensor(51.6114, grad_fn=<MeanBackward1>) 16200
# tensor(51.7390, grad_fn=<MeanBackward1>) 16300
# tensor(51.5970, grad_fn=<MeanBackward1>) 16400
# tensor(51.5639, grad_fn=<MeanBackward1>) 16500
# tensor(51.5824, grad_fn=<MeanBackward1>) 16600
# tensor(51.3093, grad_fn=<MeanBackward1>) 16700
# tensor(51.2397, grad_fn=<MeanBackward1>) 16800
# tensor(51.3334, grad_fn=<MeanBackward1>) 16900
# tensor(51.1369, grad_fn=<MeanBackward1>) 17000
# tensor(51.1022, grad_fn=<MeanBackward1>) 17100
# tensor(51.0835, grad_fn=<MeanBackward1>) 17200
# tensor(50.9157, grad_fn=<MeanBackward1>) 17300
# tensor(51.0313, grad_fn=<MeanBackward1>) 17400
# tensor(50.8551, grad_fn=<MeanBackward1>) 17500
# tensor(50.9182, grad_fn=<MeanBackward1>) 17600
# tensor(50.9605, grad_fn=<MeanBackward1>) 17700
# tensor(50.5727, grad_fn=<MeanBackward1>) 17800
# tensor(50.6557, grad_fn=<MeanBackward1>) 17900
# tensor(50.5830, grad_fn=<MeanBackward1>) 18000
# tensor(51.3496, grad_fn=<MeanBackward1>) 18100
# tensor(50.6740, grad_fn=<MeanBackward1>) 18200
# tensor(50.6474, grad_fn=<MeanBackward1>) 18300
# tensor(50.3551, grad_fn=<MeanBackward1>) 18400
# tensor(50.4316, grad_fn=<MeanBackward1>) 18500
# tensor(50.2906, grad_fn=<MeanBackward1>) 18600
# tensor(50.1929, grad_fn=<MeanBackward1>) 18700
# tensor(49.8482, grad_fn=<MeanBackward1>) 18800
# tensor(50.0350, grad_fn=<MeanBackward1>) 18900
# tensor(49.9268, grad_fn=<MeanBackward1>) 19000
# tensor(55.0808, grad_fn=<MeanBackward1>) 19100
# tensor(55.0422, grad_fn=<MeanBackward1>) 19200
# tensor(55.0611, grad_fn=<MeanBackward1>) 19300
# tensor(54.9908, grad_fn=<MeanBackward1>) 19400
# tensor(55.0197, grad_fn=<MeanBackward1>) 19500
# tensor(54.7628, grad_fn=<MeanBackward1>) 19600
# tensor(55.0327, grad_fn=<MeanBackward1>) 19700
# tensor(54.9894, grad_fn=<MeanBackward1>) 19800
# tensor(55.0406, grad_fn=<MeanBackward1>) 19900
# tensor(55.0005, grad_fn=<MeanBackward1>) 20000
# tensor(55.0638, grad_fn=<MeanBackward1>) 20100
# tensor(54.9087, grad_fn=<MeanBackward1>) 20200
# tensor(54.9818, grad_fn=<MeanBackward1>) 20300
# tensor(54.8832, grad_fn=<MeanBackward1>) 20400
# tensor(54.9210, grad_fn=<MeanBackward1>) 20500
# tensor(54.9845, grad_fn=<MeanBackward1>) 20600
# tensor(54.8936, grad_fn=<MeanBackward1>) 20700
# tensor(54.9205, grad_fn=<MeanBackward1>) 20800
# tensor(54.9985, grad_fn=<MeanBackward1>) 20900
# tensor(55.0156, grad_fn=<MeanBackward1>) 21000
# tensor(54.9878, grad_fn=<MeanBackward1>) 21100
# tensor(55.0549, grad_fn=<MeanBackward1>) 21200
# tensor(55.0699, grad_fn=<MeanBackward1>) 21300
# tensor(55.0413, grad_fn=<MeanBackward1>) 21400
# tensor(55.0118, grad_fn=<MeanBackward1>) 21500
# tensor(55.0065, grad_fn=<MeanBackward1>) 21600
# tensor(54.9441, grad_fn=<MeanBackward1>) 21700
# tensor(55.0354, grad_fn=<MeanBackward1>) 21800
# tensor(55.1003, grad_fn=<MeanBackward1>) 21900
# tensor(55.0908, grad_fn=<MeanBackward1>) 22000
# tensor(54.9972, grad_fn=<MeanBackward1>) 22100
# tensor(54.9869, grad_fn=<MeanBackward1>) 22200
# tensor(55.0231, grad_fn=<MeanBackward1>) 22300
# tensor(54.9920, grad_fn=<MeanBackward1>) 22400
# tensor(54.9705, grad_fn=<MeanBackward1>) 22500
# tensor(55.0478, grad_fn=<MeanBackward1>) 22600
# tensor(54.9662, grad_fn=<MeanBackward1>) 22700
# tensor(54.9586, grad_fn=<MeanBackward1>) 22800
# tensor(55.0058, grad_fn=<MeanBackward1>) 22900
# tensor(54.9445, grad_fn=<MeanBackward1>) 23000
# tensor(55.1421, grad_fn=<MeanBackward1>) 23100
# tensor(54.9611, grad_fn=<MeanBackward1>) 23200
# tensor(54.9083, grad_fn=<MeanBackward1>) 23300
# tensor(54.9357, grad_fn=<MeanBackward1>) 23400
# tensor(54.8816, grad_fn=<MeanBackward1>) 23500
# tensor(54.9746, grad_fn=<MeanBackward1>) 23600
# tensor(54.9894, grad_fn=<MeanBackward1>) 23700
# tensor(54.9531, grad_fn=<MeanBackward1>) 23800
# tensor(14448804., grad_fn=<MeanBackward1>) 23900
# tensor(54.9325, grad_fn=<MeanBackward1>) 24000
# tensor(54.9389, grad_fn=<MeanBackward1>) 24100
# tensor(55.0661, grad_fn=<MeanBackward1>) 24200
# tensor(55.0374, grad_fn=<MeanBackward1>) 24300
# tensor(54.8352, grad_fn=<MeanBackward1>) 24400
# tensor(55.0013, grad_fn=<MeanBackward1>) 24500
# tensor(54.9397, grad_fn=<MeanBackward1>) 24600
# tensor(54.8990, grad_fn=<MeanBackward1>) 24700
# tensor(55.0171, grad_fn=<MeanBackward1>) 24800
# tensor(54.9866, grad_fn=<MeanBackward1>) 24900
# tensor(54.9926, grad_fn=<MeanBackward1>) 25000
# tensor(55.0258, grad_fn=<MeanBackward1>) 25100
# tensor(54.9339, grad_fn=<MeanBackward1>) 25200
# tensor(55.0887, grad_fn=<MeanBackward1>) 25300
# tensor(55.0657, grad_fn=<MeanBackward1>) 25400
# tensor(55.0415, grad_fn=<MeanBackward1>) 25500
# tensor(55.1332, grad_fn=<MeanBackward1>) 25600
# tensor(54.9943, grad_fn=<MeanBackward1>) 25700
# tensor(55.0936, grad_fn=<MeanBackward1>) 25800
# tensor(55.0143, grad_fn=<MeanBackward1>) 25900
# tensor(54.9486, grad_fn=<MeanBackward1>) 26000
# tensor(55.0220, grad_fn=<MeanBackward1>) 26100
# tensor(54.7749, grad_fn=<MeanBackward1>) 26200
# tensor(55.0033, grad_fn=<MeanBackward1>) 26300
# tensor(54.9831, grad_fn=<MeanBackward1>) 26400
# tensor(55.0282, grad_fn=<MeanBackward1>) 26500
# tensor(55.0340, grad_fn=<MeanBackward1>) 26600
# tensor(55.0262, grad_fn=<MeanBackward1>) 26700
# tensor(55.0176, grad_fn=<MeanBackward1>) 26800
# tensor(54.8785, grad_fn=<MeanBackward1>) 26900
# tensor(55.1699, grad_fn=<MeanBackward1>) 27000
# tensor(55.0323, grad_fn=<MeanBackward1>) 27100
# tensor(55.0011, grad_fn=<MeanBackward1>) 27200
# tensor(55.0685, grad_fn=<MeanBackward1>) 27300
# tensor(54.9081, grad_fn=<MeanBackward1>) 27400
# tensor(55.0728, grad_fn=<MeanBackward1>) 27500
# tensor(55.0428, grad_fn=<MeanBackward1>) 27600
# tensor(55.0193, grad_fn=<MeanBackward1>) 27700
# tensor(55.1618, grad_fn=<MeanBackward1>) 27800
# tensor(55.1266, grad_fn=<MeanBackward1>) 27900
# tensor(55.1755, grad_fn=<MeanBackward1>) 28000
# tensor(55.0963, grad_fn=<MeanBackward1>) 28100
# tensor(54.9894, grad_fn=<MeanBackward1>) 28200
# tensor(55.0561, grad_fn=<MeanBackward1>) 28300
# tensor(55.0280, grad_fn=<MeanBackward1>) 28400
# tensor(55.1005, grad_fn=<MeanBackward1>) 28500
# tensor(54.9181, grad_fn=<MeanBackward1>) 28600
# tensor(54.8269, grad_fn=<MeanBackward1>) 28700
# tensor(55.0079, grad_fn=<MeanBackward1>) 28800
# tensor(55.0678, grad_fn=<MeanBackward1>) 28900
# tensor(54.9783, grad_fn=<MeanBackward1>) 29000
# tensor(54.9366, grad_fn=<MeanBackward1>) 29100
# tensor(54.9885, grad_fn=<MeanBackward1>) 29200
# tensor(55.0397, grad_fn=<MeanBackward1>) 29300
# tensor(54.9842, grad_fn=<MeanBackward1>) 29400
# tensor(55.1045, grad_fn=<MeanBackward1>) 29500
# tensor(55.0197, grad_fn=<MeanBackward1>) 29600
# tensor(54.8976, grad_fn=<MeanBackward1>) 29700
# tensor(55.0382, grad_fn=<MeanBackward1>) 29800
# tensor(55.0600, grad_fn=<MeanBackward1>) 29900
# tensor(54.9211, grad_fn=<MeanBackward1>) 30000
# tensor(54.9994, grad_fn=<MeanBackward1>) 30100
# tensor(54.9293, grad_fn=<MeanBackward1>) 30200
# tensor(54.9877, grad_fn=<MeanBackward1>) 30300
# tensor(54.9735, grad_fn=<MeanBackward1>) 30400
# tensor(54.9358, grad_fn=<MeanBackward1>) 30500
# tensor(55.0010, grad_fn=<MeanBackward1>) 30600
# tensor(55.0233, grad_fn=<MeanBackward1>) 30700
# tensor(54.9908, grad_fn=<MeanBackward1>) 30800
# tensor(54.9217, grad_fn=<MeanBackward1>) 30900
# tensor(55.0386, grad_fn=<MeanBackward1>) 31000
# tensor(55.0134, grad_fn=<MeanBackward1>) 31100
# tensor(55.0224, grad_fn=<MeanBackward1>) 31200
# tensor(54.9720, grad_fn=<MeanBackward1>) 31300
# tensor(55.0648, grad_fn=<MeanBackward1>) 31400
# tensor(54.9904, grad_fn=<MeanBackward1>) 31500
# tensor(55.1796, grad_fn=<MeanBackward1>) 31600
# tensor(55.0376, grad_fn=<MeanBackward1>) 31700
# tensor(55.0481, grad_fn=<MeanBackward1>) 31800
# tensor(55.1096, grad_fn=<MeanBackward1>) 31900
# tensor(55.0516, grad_fn=<MeanBackward1>) 32000
# tensor(55.0014, grad_fn=<MeanBackward1>) 32100
# tensor(54.9424, grad_fn=<MeanBackward1>) 32200
# tensor(54.9542, grad_fn=<MeanBackward1>) 32300
# tensor(55.0329, grad_fn=<MeanBackward1>) 32400
# tensor(55.0318, grad_fn=<MeanBackward1>) 32500
# tensor(54.9388, grad_fn=<MeanBackward1>) 32600
# tensor(55.0165, grad_fn=<MeanBackward1>) 32700
# tensor(55.1017, grad_fn=<MeanBackward1>) 32800
# tensor(55.0881, grad_fn=<MeanBackward1>) 32900
# tensor(54.9048, grad_fn=<MeanBackward1>) 33000
# tensor(55.0190, grad_fn=<MeanBackward1>) 33100
# tensor(54.8554, grad_fn=<MeanBackward1>) 33200
# tensor(55.0144, grad_fn=<MeanBackward1>) 33300
# tensor(54.9266, grad_fn=<MeanBackward1>) 33400
# tensor(54.9251, grad_fn=<MeanBackward1>) 33500
# tensor(55.1138, grad_fn=<MeanBackward1>) 33600
# tensor(54.9145, grad_fn=<MeanBackward1>) 33700
# tensor(55.0918, grad_fn=<MeanBackward1>) 33800
# tensor(54.9820, grad_fn=<MeanBackward1>) 33900
# tensor(55.0753, grad_fn=<MeanBackward1>) 34000
# tensor(54.9097, grad_fn=<MeanBackward1>) 34100
# tensor(54.9666, grad_fn=<MeanBackward1>) 34200
# tensor(54.9244, grad_fn=<MeanBackward1>) 34300
# tensor(54.9435, grad_fn=<MeanBackward1>) 34400
# tensor(55.0844, grad_fn=<MeanBackward1>) 34500
# tensor(54.9510, grad_fn=<MeanBackward1>) 34600
# tensor(54.9738, grad_fn=<MeanBackward1>) 34700
# tensor(55.0227, grad_fn=<MeanBackward1>) 34800
# tensor(55.0733, grad_fn=<MeanBackward1>) 34900
# tensor(54.9251, grad_fn=<MeanBackward1>) 35000
# tensor(54.9680, grad_fn=<MeanBackward1>) 35100
# tensor(55.0186, grad_fn=<MeanBackward1>) 35200
# tensor(54.9962, grad_fn=<MeanBackward1>) 35300
# tensor(55.1585, grad_fn=<MeanBackward1>) 35400
# tensor(55.0197, grad_fn=<MeanBackward1>) 35500
# tensor(55.0153, grad_fn=<MeanBackward1>) 35600
# tensor(55.0824, grad_fn=<MeanBackward1>) 35700
# tensor(54.9646, grad_fn=<MeanBackward1>) 35800
# tensor(54.8433, grad_fn=<MeanBackward1>) 35900
# tensor(54.8634, grad_fn=<MeanBackward1>) 36000
# tensor(54.9436, grad_fn=<MeanBackward1>) 36100
# tensor(54.9094, grad_fn=<MeanBackward1>) 36200
# tensor(55.2569, grad_fn=<MeanBackward1>) 36300
# tensor(55.0537, grad_fn=<MeanBackward1>) 36400
# tensor(54.9344, grad_fn=<MeanBackward1>) 36500
# tensor(55.1062, grad_fn=<MeanBackward1>) 36600
# tensor(55.0950, grad_fn=<MeanBackward1>) 36700
# tensor(54.9751, grad_fn=<MeanBackward1>) 36800
# tensor(54.9708, grad_fn=<MeanBackward1>) 36900
# tensor(54.9360, grad_fn=<MeanBackward1>) 37000
# tensor(55.0016, grad_fn=<MeanBackward1>) 37100
# tensor(55.0416, grad_fn=<MeanBackward1>) 37200
# tensor(55.0827, grad_fn=<MeanBackward1>) 37300
# tensor(55.1016, grad_fn=<MeanBackward1>) 37400
# tensor(55.1022, grad_fn=<MeanBackward1>) 37500
# tensor(55.1104, grad_fn=<MeanBackward1>) 37600
# tensor(55.0224, grad_fn=<MeanBackward1>) 37700
# tensor(55.0493, grad_fn=<MeanBackward1>) 37800
# tensor(54.9674, grad_fn=<MeanBackward1>) 37900
# tensor(55.0945, grad_fn=<MeanBackward1>) 38000
# tensor(55.0265, grad_fn=<MeanBackward1>) 38100
# tensor(54.9127, grad_fn=<MeanBackward1>) 38200
# tensor(54.9441, grad_fn=<MeanBackward1>) 38300
# tensor(55.0221, grad_fn=<MeanBackward1>) 38400
# tensor(55.1377, grad_fn=<MeanBackward1>) 38500
# tensor(55.0368, grad_fn=<MeanBackward1>) 38600
# tensor(54.9406, grad_fn=<MeanBackward1>) 38700
# tensor(55.0711, grad_fn=<MeanBackward1>) 38800
# tensor(55.0413, grad_fn=<MeanBackward1>) 38900
# tensor(55.0857, grad_fn=<MeanBackward1>) 39000
# tensor(55.0617, grad_fn=<MeanBackward1>) 39100
# tensor(54.9927, grad_fn=<MeanBackward1>) 39200
# tensor(55.0084, grad_fn=<MeanBackward1>) 39300
# tensor(55.0406, grad_fn=<MeanBackward1>) 39400
# tensor(54.9973, grad_fn=<MeanBackward1>) 39500
# tensor(55.0557, grad_fn=<MeanBackward1>) 39600
# tensor(54.8795, grad_fn=<MeanBackward1>) 39700
# tensor(54.8993, grad_fn=<MeanBackward1>) 39800
# tensor(55.0735, grad_fn=<MeanBackward1>) 39900
# tensor(54.9297, grad_fn=<MeanBackward1>) 40000
# tensor(55.1068, grad_fn=<MeanBackward1>) 40100
# tensor(55.1812, grad_fn=<MeanBackward1>) 40200
# tensor(54.9977, grad_fn=<MeanBackward1>) 40300
# tensor(55.1696, grad_fn=<MeanBackward1>) 40400
# tensor(54.9300, grad_fn=<MeanBackward1>) 40500
# tensor(54.9957, grad_fn=<MeanBackward1>) 40600
# tensor(55.1201, grad_fn=<MeanBackward1>) 40700
# tensor(55.0593, grad_fn=<MeanBackward1>) 40800
# tensor(54.9428, grad_fn=<MeanBackward1>) 40900
# tensor(55.0206, grad_fn=<MeanBackward1>) 41000
# tensor(55.0699, grad_fn=<MeanBackward1>) 41100
# tensor(54.8481, grad_fn=<MeanBackward1>) 41200
# tensor(54.9802, grad_fn=<MeanBackward1>) 41300
# tensor(54.9438, grad_fn=<MeanBackward1>) 41400
# tensor(55.0349, grad_fn=<MeanBackward1>) 41500
# tensor(54.9653, grad_fn=<MeanBackward1>) 41600
# tensor(55.1008, grad_fn=<MeanBackward1>) 41700
# tensor(55.0375, grad_fn=<MeanBackward1>) 41800
# tensor(54.9615, grad_fn=<MeanBackward1>) 41900
# tensor(55.1132, grad_fn=<MeanBackward1>) 42000
# tensor(54.9837, grad_fn=<MeanBackward1>) 42100
# tensor(55.0082, grad_fn=<MeanBackward1>) 42200
# tensor(54.8474, grad_fn=<MeanBackward1>) 42300
# tensor(54.8952, grad_fn=<MeanBackward1>) 42400
# tensor(54.9878, grad_fn=<MeanBackward1>) 42500
# tensor(54.9732, grad_fn=<MeanBackward1>) 42600
# tensor(55.0393, grad_fn=<MeanBackward1>) 42700
# tensor(55.0093, grad_fn=<MeanBackward1>) 42800
# tensor(54.9516, grad_fn=<MeanBackward1>) 42900
# tensor(54.8773, grad_fn=<MeanBackward1>) 43000
# tensor(54.9706, grad_fn=<MeanBackward1>) 43100
# tensor(54.9841, grad_fn=<MeanBackward1>) 43200
# tensor(55.0134, grad_fn=<MeanBackward1>) 43300
# tensor(54.7799, grad_fn=<MeanBackward1>) 43400
# tensor(54.9453, grad_fn=<MeanBackward1>) 43500
# tensor(55.0143, grad_fn=<MeanBackward1>) 43600
# tensor(54.9320, grad_fn=<MeanBackward1>) 43700
# tensor(54.9931, grad_fn=<MeanBackward1>) 43800
# tensor(55.1311, grad_fn=<MeanBackward1>) 43900
# tensor(54.9767, grad_fn=<MeanBackward1>) 44000
# tensor(55.1969, grad_fn=<MeanBackward1>) 44100
# tensor(55.0410, grad_fn=<MeanBackward1>) 44200
# tensor(54.8940, grad_fn=<MeanBackward1>) 44300
# tensor(55.0581, grad_fn=<MeanBackward1>) 44400
# tensor(55.1399, grad_fn=<MeanBackward1>) 44500
# tensor(54.9461, grad_fn=<MeanBackward1>) 44600
# tensor(54.9943, grad_fn=<MeanBackward1>) 44700
# tensor(54.9824, grad_fn=<MeanBackward1>) 44800
# tensor(54.8742, grad_fn=<MeanBackward1>) 44900
# tensor(55.1606, grad_fn=<MeanBackward1>) 45000
# tensor(55.0518, grad_fn=<MeanBackward1>) 45100
# tensor(55.0766, grad_fn=<MeanBackward1>) 45200
# tensor(55.0009, grad_fn=<MeanBackward1>) 45300
# tensor(55.0679, grad_fn=<MeanBackward1>) 45400
# tensor(54.9968, grad_fn=<MeanBackward1>) 45500
# tensor(54.8970, grad_fn=<MeanBackward1>) 45600
# tensor(55.1661, grad_fn=<MeanBackward1>) 45700
# tensor(55.0552, grad_fn=<MeanBackward1>) 45800
# tensor(54.9265, grad_fn=<MeanBackward1>) 45900
# tensor(54.9307, grad_fn=<MeanBackward1>) 46000
# tensor(55.0037, grad_fn=<MeanBackward1>) 46100
# tensor(55.0233, grad_fn=<MeanBackward1>) 46200
# tensor(55.0420, grad_fn=<MeanBackward1>) 46300
# tensor(54.9846, grad_fn=<MeanBackward1>) 46400
# tensor(55.0730, grad_fn=<MeanBackward1>) 46500
# tensor(54.9813, grad_fn=<MeanBackward1>) 46600
# tensor(54.8444, grad_fn=<MeanBackward1>) 46700
# tensor(55.0856, grad_fn=<MeanBackward1>) 46800
# tensor(55.0868, grad_fn=<MeanBackward1>) 46900
# tensor(54.8875, grad_fn=<MeanBackward1>) 47000
# tensor(54.8894, grad_fn=<MeanBackward1>) 47100
# tensor(54.9214, grad_fn=<MeanBackward1>) 47200
# tensor(54.9783, grad_fn=<MeanBackward1>) 47300
# tensor(55.0668, grad_fn=<MeanBackward1>) 47400
# tensor(54.9474, grad_fn=<MeanBackward1>) 47500
# tensor(54.9220, grad_fn=<MeanBackward1>) 47600
# tensor(55.1134, grad_fn=<MeanBackward1>) 47700
# tensor(55.0734, grad_fn=<MeanBackward1>) 47800
# tensor(55.2267, grad_fn=<MeanBackward1>) 47900
# tensor(55.0025, grad_fn=<MeanBackward1>) 48000
# tensor(54.9846, grad_fn=<MeanBackward1>) 48100
# tensor(54.9507, grad_fn=<MeanBackward1>) 48200
# tensor(55.0583, grad_fn=<MeanBackward1>) 48300
# tensor(54.9972, grad_fn=<MeanBackward1>) 48400
# tensor(54.9678, grad_fn=<MeanBackward1>) 48500
# tensor(54.9981, grad_fn=<MeanBackward1>) 48600
# tensor(55.0819, grad_fn=<MeanBackward1>) 48700
# tensor(55.0852, grad_fn=<MeanBackward1>) 48800
# tensor(55.0277, grad_fn=<MeanBackward1>) 48900
# tensor(55.1346, grad_fn=<MeanBackward1>) 49000
# tensor(54.9799, grad_fn=<MeanBackward1>) 49100
# tensor(55.0255, grad_fn=<MeanBackward1>) 49200
# tensor(55.0838, grad_fn=<MeanBackward1>) 49300
# tensor(55.0947, grad_fn=<MeanBackward1>) 49400
# tensor(55.0171, grad_fn=<MeanBackward1>) 49500
# tensor(54.9620, grad_fn=<MeanBackward1>) 49600
# tensor(55.1477, grad_fn=<MeanBackward1>) 49700
# tensor(54.9365, grad_fn=<MeanBackward1>) 49800
# tensor(54.9301, grad_fn=<MeanBackward1>) 49900
# tensor(55.1180, grad_fn=<MeanBackward1>) 50000
# tensor(54.9728, grad_fn=<MeanBackward1>) 50100
# tensor(54.9928, grad_fn=<MeanBackward1>) 50200
# tensor(54.9634, grad_fn=<MeanBackward1>) 50300
# tensor(55.0859, grad_fn=<MeanBackward1>) 50400
# tensor(54.9091, grad_fn=<MeanBackward1>) 50500
# tensor(55.0041, grad_fn=<MeanBackward1>) 50600
# tensor(54.9757, grad_fn=<MeanBackward1>) 50700
# tensor(55.0192, grad_fn=<MeanBackward1>) 50800
# tensor(55.0936, grad_fn=<MeanBackward1>) 50900
# tensor(55.0100, grad_fn=<MeanBackward1>) 51000
# tensor(55.0624, grad_fn=<MeanBackward1>) 51100
# tensor(55.0352, grad_fn=<MeanBackward1>) 51200
# tensor(55.0857, grad_fn=<MeanBackward1>) 51300
# tensor(54.9820, grad_fn=<MeanBackward1>) 51400
# tensor(55.0065, grad_fn=<MeanBackward1>) 51500
# tensor(55.0555, grad_fn=<MeanBackward1>) 51600
# tensor(54.9819, grad_fn=<MeanBackward1>) 51700
# tensor(55.1285, grad_fn=<MeanBackward1>) 51800
# tensor(55.0757, grad_fn=<MeanBackward1>) 51900
# tensor(55.2112, grad_fn=<MeanBackward1>) 52000
# tensor(55.0142, grad_fn=<MeanBackward1>) 52100
# tensor(54.9665, grad_fn=<MeanBackward1>) 52200
# tensor(54.9120, grad_fn=<MeanBackward1>) 52300
# tensor(54.9873, grad_fn=<MeanBackward1>) 52400
# tensor(55.0262, grad_fn=<MeanBackward1>) 52500
# tensor(54.9740, grad_fn=<MeanBackward1>) 52600
# tensor(54.9771, grad_fn=<MeanBackward1>) 52700
# tensor(55.1052, grad_fn=<MeanBackward1>) 52800
# tensor(54.9413, grad_fn=<MeanBackward1>) 52900
# tensor(55.1039, grad_fn=<MeanBackward1>) 53000
# tensor(54.9693, grad_fn=<MeanBackward1>) 53100
# tensor(55.1402, grad_fn=<MeanBackward1>) 53200
# tensor(55.0013, grad_fn=<MeanBackward1>) 53300
# tensor(54.9510, grad_fn=<MeanBackward1>) 53400
# tensor(54.9308, grad_fn=<MeanBackward1>) 53500
# tensor(54.9661, grad_fn=<MeanBackward1>) 53600
# tensor(55.0867, grad_fn=<MeanBackward1>) 53700
# tensor(54.8999, grad_fn=<MeanBackward1>) 53800
# tensor(54.9014, grad_fn=<MeanBackward1>) 53900
# tensor(54.8631, grad_fn=<MeanBackward1>) 54000
# tensor(54.9767, grad_fn=<MeanBackward1>) 54100
# tensor(54.9951, grad_fn=<MeanBackward1>) 54200
# tensor(55.0414, grad_fn=<MeanBackward1>) 54300
# tensor(54.9916, grad_fn=<MeanBackward1>) 54400
# tensor(55.0244, grad_fn=<MeanBackward1>) 54500
# tensor(55.0093, grad_fn=<MeanBackward1>) 54600
# tensor(55.0627, grad_fn=<MeanBackward1>) 54700
# tensor(54.9967, grad_fn=<MeanBackward1>) 54800
# tensor(55.0751, grad_fn=<MeanBackward1>) 54900
# tensor(54.9228, grad_fn=<MeanBackward1>) 55000
# tensor(55.1307, grad_fn=<MeanBackward1>) 55100
# tensor(55.0182, grad_fn=<MeanBackward1>) 55200
# tensor(55.0883, grad_fn=<MeanBackward1>) 55300
# tensor(55.0092, grad_fn=<MeanBackward1>) 55400
# tensor(54.9492, grad_fn=<MeanBackward1>) 55500
# tensor(55.0138, grad_fn=<MeanBackward1>) 55600
# tensor(54.9439, grad_fn=<MeanBackward1>) 55700
# tensor(55.0780, grad_fn=<MeanBackward1>) 55800
# tensor(55.0682, grad_fn=<MeanBackward1>) 55900
# tensor(54.9605, grad_fn=<MeanBackward1>) 56000
# tensor(54.9525, grad_fn=<MeanBackward1>) 56100
# tensor(55.0358, grad_fn=<MeanBackward1>) 56200
# tensor(54.9761, grad_fn=<MeanBackward1>) 56300
# tensor(55.0802, grad_fn=<MeanBackward1>) 56400
# tensor(54.9652, grad_fn=<MeanBackward1>) 56500
# tensor(54.9146, grad_fn=<MeanBackward1>) 56600
# tensor(55.0861, grad_fn=<MeanBackward1>) 56700
# tensor(55.1018, grad_fn=<MeanBackward1>) 56800
# tensor(55.0870, grad_fn=<MeanBackward1>) 56900
# tensor(54.9896, grad_fn=<MeanBackward1>) 57000
# tensor(55.0066, grad_fn=<MeanBackward1>) 57100
# tensor(54.9846, grad_fn=<MeanBackward1>) 57200
# tensor(54.8316, grad_fn=<MeanBackward1>) 57300
# tensor(55.0259, grad_fn=<MeanBackward1>) 57400
# tensor(55.0229, grad_fn=<MeanBackward1>) 57500
# tensor(54.9732, grad_fn=<MeanBackward1>) 57600
# tensor(54.9291, grad_fn=<MeanBackward1>) 57700
# tensor(55.1017, grad_fn=<MeanBackward1>) 57800
# tensor(55.0026, grad_fn=<MeanBackward1>) 57900
# tensor(54.9056, grad_fn=<MeanBackward1>) 58000
# tensor(55.0409, grad_fn=<MeanBackward1>) 58100
# tensor(54.8829, grad_fn=<MeanBackward1>) 58200
# tensor(54.9490, grad_fn=<MeanBackward1>) 58300
# tensor(55.0006, grad_fn=<MeanBackward1>) 58400
# tensor(55.0049, grad_fn=<MeanBackward1>) 58500
# tensor(54.9433, grad_fn=<MeanBackward1>) 58600
# tensor(55.0319, grad_fn=<MeanBackward1>) 58700
# tensor(55.0122, grad_fn=<MeanBackward1>) 58800
# tensor(54.8883, grad_fn=<MeanBackward1>) 58900
# tensor(55.0176, grad_fn=<MeanBackward1>) 59000
# tensor(55.0935, grad_fn=<MeanBackward1>) 59100
# tensor(54.9764, grad_fn=<MeanBackward1>) 59200
# tensor(55.0429, grad_fn=<MeanBackward1>) 59300
# tensor(55.0290, grad_fn=<MeanBackward1>) 59400
# tensor(55.0674, grad_fn=<MeanBackward1>) 59500
# tensor(54.9611, grad_fn=<MeanBackward1>) 59600
# tensor(54.9632, grad_fn=<MeanBackward1>) 59700
# tensor(55.0263, grad_fn=<MeanBackward1>) 59800
# tensor(55.1282, grad_fn=<MeanBackward1>) 59900
# tensor(54.9370, grad_fn=<MeanBackward1>) 60000
# tensor(55.0519, grad_fn=<MeanBackward1>) 60100
# tensor(54.9845, grad_fn=<MeanBackward1>) 60200
# tensor(55.0708, grad_fn=<MeanBackward1>) 60300
# tensor(54.9593, grad_fn=<MeanBackward1>) 60400
# tensor(54.9124, grad_fn=<MeanBackward1>) 60500
# tensor(54.9606, grad_fn=<MeanBackward1>) 60600
# tensor(54.9745, grad_fn=<MeanBackward1>) 60700
# tensor(55.2325, grad_fn=<MeanBackward1>) 60800
# tensor(55.0494, grad_fn=<MeanBackward1>) 60900
# tensor(54.9434, grad_fn=<MeanBackward1>) 61000
# tensor(54.9725, grad_fn=<MeanBackward1>) 61100
# tensor(55.0448, grad_fn=<MeanBackward1>) 61200
# tensor(55.1198, grad_fn=<MeanBackward1>) 61300
# tensor(55.1041, grad_fn=<MeanBackward1>) 61400
# tensor(55.0454, grad_fn=<MeanBackward1>) 61500
# tensor(55.0749, grad_fn=<MeanBackward1>) 61600
# tensor(54.9835, grad_fn=<MeanBackward1>) 61700
# tensor(54.9968, grad_fn=<MeanBackward1>) 61800
# tensor(55.0288, grad_fn=<MeanBackward1>) 61900
# tensor(54.9442, grad_fn=<MeanBackward1>) 62000
# tensor(54.9951, grad_fn=<MeanBackward1>) 62100
# tensor(55.0802, grad_fn=<MeanBackward1>) 62200
# tensor(55.0018, grad_fn=<MeanBackward1>) 62300
# tensor(54.9441, grad_fn=<MeanBackward1>) 62400
# tensor(55.0466, grad_fn=<MeanBackward1>) 62500
# tensor(55.0981, grad_fn=<MeanBackward1>) 62600
# tensor(55.0875, grad_fn=<MeanBackward1>) 62700
# tensor(55.1036, grad_fn=<MeanBackward1>) 62800
# tensor(55.0111, grad_fn=<MeanBackward1>) 62900
# tensor(55.0700, grad_fn=<MeanBackward1>) 63000
# tensor(55.1185, grad_fn=<MeanBackward1>) 63100
# tensor(55.0826, grad_fn=<MeanBackward1>) 63200
# tensor(55.0104, grad_fn=<MeanBackward1>) 63300
# tensor(55.0878, grad_fn=<MeanBackward1>) 63400
# tensor(54.9956, grad_fn=<MeanBackward1>) 63500
# tensor(55.0697, grad_fn=<MeanBackward1>) 63600
# tensor(55.0419, grad_fn=<MeanBackward1>) 63700
# tensor(54.8854, grad_fn=<MeanBackward1>) 63800
# tensor(55.1197, grad_fn=<MeanBackward1>) 63900
# tensor(55.0543, grad_fn=<MeanBackward1>) 64000
# tensor(55.0929, grad_fn=<MeanBackward1>) 64100
# tensor(54.9787, grad_fn=<MeanBackward1>) 64200
# tensor(54.9356, grad_fn=<MeanBackward1>) 64300
# tensor(54.9823, grad_fn=<MeanBackward1>) 64400
# tensor(55.0315, grad_fn=<MeanBackward1>) 64500
# tensor(55.0078, grad_fn=<MeanBackward1>) 64600
# tensor(55.0477, grad_fn=<MeanBackward1>) 64700
# tensor(54.9245, grad_fn=<MeanBackward1>) 64800
# tensor(54.9964, grad_fn=<MeanBackward1>) 64900
# tensor(55.0139, grad_fn=<MeanBackward1>) 65000
# tensor(55.1186, grad_fn=<MeanBackward1>) 65100
# tensor(55.0355, grad_fn=<MeanBackward1>) 65200
# tensor(54.9682, grad_fn=<MeanBackward1>) 65300
# tensor(54.9767, grad_fn=<MeanBackward1>) 65400
# tensor(55.0054, grad_fn=<MeanBackward1>) 65500
# tensor(54.9418, grad_fn=<MeanBackward1>) 65600
# tensor(55.0168, grad_fn=<MeanBackward1>) 65700
# tensor(55.0790, grad_fn=<MeanBackward1>) 65800
# tensor(54.9434, grad_fn=<MeanBackward1>) 65900
# tensor(54.9899, grad_fn=<MeanBackward1>) 66000
# tensor(55.1394, grad_fn=<MeanBackward1>) 66100
# tensor(54.9814, grad_fn=<MeanBackward1>) 66200
# tensor(55.0229, grad_fn=<MeanBackward1>) 66300
# tensor(54.9105, grad_fn=<MeanBackward1>) 66400
# tensor(55.0286, grad_fn=<MeanBackward1>) 66500
# tensor(55.0568, grad_fn=<MeanBackward1>) 66600
# tensor(54.9526, grad_fn=<MeanBackward1>) 66700
# tensor(54.9584, grad_fn=<MeanBackward1>) 66800
# tensor(55.0165, grad_fn=<MeanBackward1>) 66900
# tensor(54.9413, grad_fn=<MeanBackward1>) 67000
# tensor(55.0321, grad_fn=<MeanBackward1>) 67100
# tensor(54.9989, grad_fn=<MeanBackward1>) 67200
# tensor(55.0136, grad_fn=<MeanBackward1>) 67300
# tensor(55.1095, grad_fn=<MeanBackward1>) 67400
# tensor(55.0066, grad_fn=<MeanBackward1>) 67500
# tensor(55.0191, grad_fn=<MeanBackward1>) 67600
# tensor(55.1525, grad_fn=<MeanBackward1>) 67700
# tensor(55.0380, grad_fn=<MeanBackward1>) 67800
# tensor(55.1168, grad_fn=<MeanBackward1>) 67900
# tensor(55.0626, grad_fn=<MeanBackward1>) 68000
# tensor(54.9100, grad_fn=<MeanBackward1>) 68100
# tensor(54.8568, grad_fn=<MeanBackward1>) 68200
# tensor(55.0082, grad_fn=<MeanBackward1>) 68300
# tensor(55.0804, grad_fn=<MeanBackward1>) 68400
# tensor(55.0504, grad_fn=<MeanBackward1>) 68500
# tensor(55.1280, grad_fn=<MeanBackward1>) 68600
# tensor(55.0005, grad_fn=<MeanBackward1>) 68700
# tensor(55.0830, grad_fn=<MeanBackward1>) 68800
# tensor(55.0140, grad_fn=<MeanBackward1>) 68900
# tensor(55.0428, grad_fn=<MeanBackward1>) 69000
# tensor(55.0064, grad_fn=<MeanBackward1>) 69100
# tensor(54.9919, grad_fn=<MeanBackward1>) 69200
# tensor(55.0629, grad_fn=<MeanBackward1>) 69300
# tensor(55.0326, grad_fn=<MeanBackward1>) 69400
# tensor(54.9892, grad_fn=<MeanBackward1>) 69500
# tensor(54.9372, grad_fn=<MeanBackward1>) 69600
# tensor(55.2134, grad_fn=<MeanBackward1>) 69700
# tensor(54.9541, grad_fn=<MeanBackward1>) 69800
# tensor(55.0761, grad_fn=<MeanBackward1>) 69900
# tensor(55.0024, grad_fn=<MeanBackward1>) 70000
# tensor(55.1521, grad_fn=<MeanBackward1>) 70100
# tensor(55.0326, grad_fn=<MeanBackward1>) 70200
# tensor(55.0287, grad_fn=<MeanBackward1>) 70300
# tensor(55.0612, grad_fn=<MeanBackward1>) 70400
# tensor(54.9694, grad_fn=<MeanBackward1>) 70500
# tensor(54.9653, grad_fn=<MeanBackward1>) 70600
# tensor(54.9221, grad_fn=<MeanBackward1>) 70700
# tensor(54.9485, grad_fn=<MeanBackward1>) 70800
# tensor(54.9963, grad_fn=<MeanBackward1>) 70900
# tensor(55.0553, grad_fn=<MeanBackward1>) 71000
# tensor(54.9583, grad_fn=<MeanBackward1>) 71100
# tensor(55.0822, grad_fn=<MeanBackward1>) 71200
# tensor(55.0425, grad_fn=<MeanBackward1>) 71300
# tensor(55.0139, grad_fn=<MeanBackward1>) 71400
# tensor(55.0801, grad_fn=<MeanBackward1>) 71500
# tensor(55.0370, grad_fn=<MeanBackward1>) 71600
# tensor(55.0739, grad_fn=<MeanBackward1>) 71700
# tensor(55.0434, grad_fn=<MeanBackward1>) 71800
# tensor(55.0332, grad_fn=<MeanBackward1>) 71900
# tensor(55.0822, grad_fn=<MeanBackward1>) 72000
# tensor(55.0192, grad_fn=<MeanBackward1>) 72100
# tensor(54.9024, grad_fn=<MeanBackward1>) 72200
# tensor(54.9434, grad_fn=<MeanBackward1>) 72300
# tensor(55.0590, grad_fn=<MeanBackward1>) 72400
# tensor(54.9968, grad_fn=<MeanBackward1>) 72500
# tensor(54.9442, grad_fn=<MeanBackward1>) 72600
# tensor(54.9696, grad_fn=<MeanBackward1>) 72700
# tensor(55.0868, grad_fn=<MeanBackward1>) 72800
# tensor(55.0810, grad_fn=<MeanBackward1>) 72900
# tensor(55.0501, grad_fn=<MeanBackward1>) 73000
# tensor(54.9667, grad_fn=<MeanBackward1>) 73100
# tensor(55.0175, grad_fn=<MeanBackward1>) 73200
# tensor(54.9780, grad_fn=<MeanBackward1>) 73300
# tensor(55.0292, grad_fn=<MeanBackward1>) 73400
# tensor(54.9841, grad_fn=<MeanBackward1>) 73500
# tensor(55.0692, grad_fn=<MeanBackward1>) 73600
# tensor(54.9484, grad_fn=<MeanBackward1>) 73700
# tensor(54.9621, grad_fn=<MeanBackward1>) 73800
# tensor(54.9013, grad_fn=<MeanBackward1>) 73900
# tensor(55.0659, grad_fn=<MeanBackward1>) 74000
# tensor(55.0151, grad_fn=<MeanBackward1>) 74100
# tensor(55.0468, grad_fn=<MeanBackward1>) 74200
# tensor(55.1063, grad_fn=<MeanBackward1>) 74300
# tensor(55.0275, grad_fn=<MeanBackward1>) 74400
# tensor(55.0940, grad_fn=<MeanBackward1>) 74500
# tensor(54.9018, grad_fn=<MeanBackward1>) 74600
# tensor(54.9058, grad_fn=<MeanBackward1>) 74700
# tensor(55.0527, grad_fn=<MeanBackward1>) 74800
# tensor(54.9564, grad_fn=<MeanBackward1>) 74900
# tensor(54.9816, grad_fn=<MeanBackward1>) 75000
# tensor(55.0565, grad_fn=<MeanBackward1>) 75100
# tensor(54.9954, grad_fn=<MeanBackward1>) 75200
# tensor(55.1175, grad_fn=<MeanBackward1>) 75300
# tensor(54.9809, grad_fn=<MeanBackward1>) 75400
# tensor(55.0198, grad_fn=<MeanBackward1>) 75500
# tensor(55.0168, grad_fn=<MeanBackward1>) 75600
# tensor(55.0193, grad_fn=<MeanBackward1>) 75700
# tensor(54.9268, grad_fn=<MeanBackward1>) 75800
# tensor(55.0071, grad_fn=<MeanBackward1>) 75900
# tensor(55.0072, grad_fn=<MeanBackward1>) 76000
# tensor(54.8844, grad_fn=<MeanBackward1>) 76100
# tensor(55.0846, grad_fn=<MeanBackward1>) 76200
# tensor(54.9395, grad_fn=<MeanBackward1>) 76300
# tensor(54.8911, grad_fn=<MeanBackward1>) 76400
# tensor(54.9786, grad_fn=<MeanBackward1>) 76500
# tensor(55.0377, grad_fn=<MeanBackward1>) 76600
# tensor(55.0090, grad_fn=<MeanBackward1>) 76700
# tensor(55.0554, grad_fn=<MeanBackward1>) 76800
# tensor(55.1852, grad_fn=<MeanBackward1>) 76900
# tensor(55.1299, grad_fn=<MeanBackward1>) 77000
# tensor(55.0030, grad_fn=<MeanBackward1>) 77100
# tensor(55.1339, grad_fn=<MeanBackward1>) 77200
# tensor(55.0108, grad_fn=<MeanBackward1>) 77300
# tensor(55.1168, grad_fn=<MeanBackward1>) 77400
# tensor(55.0038, grad_fn=<MeanBackward1>) 77500
# tensor(54.8875, grad_fn=<MeanBackward1>) 77600
# tensor(55.1358, grad_fn=<MeanBackward1>) 77700
# tensor(55.0790, grad_fn=<MeanBackward1>) 77800
# tensor(55.0519, grad_fn=<MeanBackward1>) 77900
# tensor(54.9366, grad_fn=<MeanBackward1>) 78000
# tensor(54.9199, grad_fn=<MeanBackward1>) 78100
# tensor(54.9899, grad_fn=<MeanBackward1>) 78200
# tensor(55.0935, grad_fn=<MeanBackward1>) 78300
# tensor(54.9355, grad_fn=<MeanBackward1>) 78400
# tensor(55.0059, grad_fn=<MeanBackward1>) 78500
# tensor(54.9168, grad_fn=<MeanBackward1>) 78600
# tensor(54.9602, grad_fn=<MeanBackward1>) 78700
# tensor(54.8385, grad_fn=<MeanBackward1>) 78800
# tensor(55.1109, grad_fn=<MeanBackward1>) 78900
# tensor(55.0439, grad_fn=<MeanBackward1>) 79000
# tensor(55.1284, grad_fn=<MeanBackward1>) 79100
# tensor(54.9977, grad_fn=<MeanBackward1>) 79200
# tensor(54.9698, grad_fn=<MeanBackward1>) 79300
# tensor(54.9999, grad_fn=<MeanBackward1>) 79400
# tensor(55.0188, grad_fn=<MeanBackward1>) 79500
# tensor(54.9373, grad_fn=<MeanBackward1>) 79600
# tensor(55.0588, grad_fn=<MeanBackward1>) 79700
# tensor(55.0658, grad_fn=<MeanBackward1>) 79800
# tensor(55.0920, grad_fn=<MeanBackward1>) 79900
# tensor(55.1252, grad_fn=<MeanBackward1>) 80000
# tensor(54.9604, grad_fn=<MeanBackward1>) 80100
# tensor(55.1079, grad_fn=<MeanBackward1>) 80200
# tensor(55.1208, grad_fn=<MeanBackward1>) 80300
# tensor(55.0450, grad_fn=<MeanBackward1>) 80400
# tensor(55.0236, grad_fn=<MeanBackward1>) 80500
# tensor(55.0008, grad_fn=<MeanBackward1>) 80600
# tensor(54.9257, grad_fn=<MeanBackward1>) 80700
# tensor(54.9695, grad_fn=<MeanBackward1>) 80800
# tensor(55.0666, grad_fn=<MeanBackward1>) 80900
# tensor(55.2385, grad_fn=<MeanBackward1>) 81000
# tensor(54.8504, grad_fn=<MeanBackward1>) 81100
# tensor(54.9747, grad_fn=<MeanBackward1>) 81200
# tensor(54.9945, grad_fn=<MeanBackward1>) 81300
# tensor(55.0630, grad_fn=<MeanBackward1>) 81400
# tensor(54.9693, grad_fn=<MeanBackward1>) 81500
# tensor(55.1509, grad_fn=<MeanBackward1>) 81600
# tensor(54.8946, grad_fn=<MeanBackward1>) 81700
# tensor(55.1316, grad_fn=<MeanBackward1>) 81800
# tensor(54.9831, grad_fn=<MeanBackward1>) 81900
# tensor(54.9714, grad_fn=<MeanBackward1>) 82000
# tensor(55., grad_fn=<MeanBackward1>) 82100
# tensor(54.9478, grad_fn=<MeanBackward1>) 82200
# tensor(54.9107, grad_fn=<MeanBackward1>) 82300
# tensor(54.9332, grad_fn=<MeanBackward1>) 82400
# tensor(55.0480, grad_fn=<MeanBackward1>) 82500
# tensor(54.9641, grad_fn=<MeanBackward1>) 82600
# tensor(55.0494, grad_fn=<MeanBackward1>) 82700
# tensor(55.0336, grad_fn=<MeanBackward1>) 82800
# tensor(55.0474, grad_fn=<MeanBackward1>) 82900
# tensor(54.9617, grad_fn=<MeanBackward1>) 83000
# tensor(55.0331, grad_fn=<MeanBackward1>) 83100
# tensor(54.9522, grad_fn=<MeanBackward1>) 83200
# tensor(54.9900, grad_fn=<MeanBackward1>) 83300
# tensor(55.2071, grad_fn=<MeanBackward1>) 83400
# tensor(54.9164, grad_fn=<MeanBackward1>) 83500
# tensor(55.0364, grad_fn=<MeanBackward1>) 83600
# tensor(54.9520, grad_fn=<MeanBackward1>) 83700
# tensor(55.0204, grad_fn=<MeanBackward1>) 83800
# tensor(54.9974, grad_fn=<MeanBackward1>) 83900
# tensor(54.9663, grad_fn=<MeanBackward1>) 84000
# tensor(54.9542, grad_fn=<MeanBackward1>) 84100
# tensor(55.0027, grad_fn=<MeanBackward1>) 84200
# tensor(54.9387, grad_fn=<MeanBackward1>) 84300
# tensor(55.0586, grad_fn=<MeanBackward1>) 84400
# tensor(54.9947, grad_fn=<MeanBackward1>) 84500
# tensor(55.0775, grad_fn=<MeanBackward1>) 84600
# tensor(54.9488, grad_fn=<MeanBackward1>) 84700
# tensor(55.0784, grad_fn=<MeanBackward1>) 84800
# tensor(54.9844, grad_fn=<MeanBackward1>) 84900
# tensor(55.0046, grad_fn=<MeanBackward1>) 85000
# tensor(55.0167, grad_fn=<MeanBackward1>) 85100
# tensor(55.0393, grad_fn=<MeanBackward1>) 85200
# tensor(54.9900, grad_fn=<MeanBackward1>) 85300
# tensor(54.8636, grad_fn=<MeanBackward1>) 85400
# tensor(54.9757, grad_fn=<MeanBackward1>) 85500
# tensor(55.0124, grad_fn=<MeanBackward1>) 85600
# tensor(55.0854, grad_fn=<MeanBackward1>) 85700
# tensor(54.9636, grad_fn=<MeanBackward1>) 85800
# tensor(54.9173, grad_fn=<MeanBackward1>) 85900
# tensor(55.0011, grad_fn=<MeanBackward1>) 86000
# tensor(55.0045, grad_fn=<MeanBackward1>) 86100
# tensor(55.0128, grad_fn=<MeanBackward1>) 86200
# tensor(55.0051, grad_fn=<MeanBackward1>) 86300
# tensor(55.1082, grad_fn=<MeanBackward1>) 86400
# tensor(54.8508, grad_fn=<MeanBackward1>) 86500
# tensor(55.0322, grad_fn=<MeanBackward1>) 86600
# tensor(55.0024, grad_fn=<MeanBackward1>) 86700
# tensor(55.1043, grad_fn=<MeanBackward1>) 86800
# tensor(54.8455, grad_fn=<MeanBackward1>) 86900
# tensor(54.9117, grad_fn=<MeanBackward1>) 87000
# tensor(54.9045, grad_fn=<MeanBackward1>) 87100
# tensor(55.1035, grad_fn=<MeanBackward1>) 87200
# tensor(54.9604, grad_fn=<MeanBackward1>) 87300
# tensor(55.1404, grad_fn=<MeanBackward1>) 87400
# tensor(55.0446, grad_fn=<MeanBackward1>) 87500
# tensor(55.0411, grad_fn=<MeanBackward1>) 87600
# tensor(54.9544, grad_fn=<MeanBackward1>) 87700
# tensor(55.0022, grad_fn=<MeanBackward1>) 87800
# tensor(55.0163, grad_fn=<MeanBackward1>) 87900
# tensor(55.0031, grad_fn=<MeanBackward1>) 88000
# tensor(55.1049, grad_fn=<MeanBackward1>) 88100
# tensor(55.0501, grad_fn=<MeanBackward1>) 88200
# tensor(54.9645, grad_fn=<MeanBackward1>) 88300
# tensor(55.1059, grad_fn=<MeanBackward1>) 88400
# tensor(54.9039, grad_fn=<MeanBackward1>) 88500
# tensor(55.0189, grad_fn=<MeanBackward1>) 88600
# tensor(55.0236, grad_fn=<MeanBackward1>) 88700
# tensor(55.1311, grad_fn=<MeanBackward1>) 88800
# tensor(54.9674, grad_fn=<MeanBackward1>) 88900
# tensor(54.8959, grad_fn=<MeanBackward1>) 89000
# tensor(54.9483, grad_fn=<MeanBackward1>) 89100
# tensor(54.8694, grad_fn=<MeanBackward1>) 89200
# tensor(54.9821, grad_fn=<MeanBackward1>) 89300
# tensor(54.9104, grad_fn=<MeanBackward1>) 89400
# tensor(55.0179, grad_fn=<MeanBackward1>) 89500
# tensor(54.9258, grad_fn=<MeanBackward1>) 89600
# tensor(55.0236, grad_fn=<MeanBackward1>) 89700
# tensor(54.9828, grad_fn=<MeanBackward1>) 89800
# tensor(55.0154, grad_fn=<MeanBackward1>) 89900
# tensor(55.0596, grad_fn=<MeanBackward1>) 90000
# tensor(54.9766, grad_fn=<MeanBackward1>) 90100
# tensor(54.9468, grad_fn=<MeanBackward1>) 90200
# tensor(55.1557, grad_fn=<MeanBackward1>) 90300
# tensor(54.9216, grad_fn=<MeanBackward1>) 90400
# tensor(55.0013, grad_fn=<MeanBackward1>) 90500
# tensor(54.9829, grad_fn=<MeanBackward1>) 90600
# tensor(55.0522, grad_fn=<MeanBackward1>) 90700
# tensor(55.1082, grad_fn=<MeanBackward1>) 90800
# tensor(55.0107, grad_fn=<MeanBackward1>) 90900
# tensor(54.8322, grad_fn=<MeanBackward1>) 91000
# tensor(54.8976, grad_fn=<MeanBackward1>) 91100
# tensor(55.0080, grad_fn=<MeanBackward1>) 91200
# tensor(55.0395, grad_fn=<MeanBackward1>) 91300
# tensor(54.9307, grad_fn=<MeanBackward1>) 91400
# tensor(54.9871, grad_fn=<MeanBackward1>) 91500
# tensor(54.9281, grad_fn=<MeanBackward1>) 91600
# tensor(55.0026, grad_fn=<MeanBackward1>) 91700
# tensor(55.0345, grad_fn=<MeanBackward1>) 91800
# tensor(55.0750, grad_fn=<MeanBackward1>) 91900
# tensor(55.0173, grad_fn=<MeanBackward1>) 92000
# tensor(55.0317, grad_fn=<MeanBackward1>) 92100
# tensor(54.9808, grad_fn=<MeanBackward1>) 92200
# tensor(55.0842, grad_fn=<MeanBackward1>) 92300
# tensor(55.0173, grad_fn=<MeanBackward1>) 92400
# tensor(55.0197, grad_fn=<MeanBackward1>) 92500
# tensor(55.1215, grad_fn=<MeanBackward1>) 92600
# tensor(54.9582, grad_fn=<MeanBackward1>) 92700
# tensor(55.0961, grad_fn=<MeanBackward1>) 92800
# tensor(55.0045, grad_fn=<MeanBackward1>) 92900
# tensor(54.9215, grad_fn=<MeanBackward1>) 93000
# tensor(54.9343, grad_fn=<MeanBackward1>) 93100
# tensor(55.1334, grad_fn=<MeanBackward1>) 93200
# tensor(55.0474, grad_fn=<MeanBackward1>) 93300
# tensor(54.8396, grad_fn=<MeanBackward1>) 93400
# tensor(55.0159, grad_fn=<MeanBackward1>) 93500
# tensor(54.8827, grad_fn=<MeanBackward1>) 93600
# tensor(54.9594, grad_fn=<MeanBackward1>) 93700
# tensor(54.9574, grad_fn=<MeanBackward1>) 93800
# tensor(55.0757, grad_fn=<MeanBackward1>) 93900
# tensor(55.1160, grad_fn=<MeanBackward1>) 94000
# tensor(54.9380, grad_fn=<MeanBackward1>) 94100
# tensor(55.0005, grad_fn=<MeanBackward1>) 94200
# tensor(54.9964, grad_fn=<MeanBackward1>) 94300
# tensor(55.1421, grad_fn=<MeanBackward1>) 94400
# tensor(54.8417, grad_fn=<MeanBackward1>) 94500
# tensor(54.9103, grad_fn=<MeanBackward1>) 94600
# tensor(54.9560, grad_fn=<MeanBackward1>) 94700
# tensor(55.0282, grad_fn=<MeanBackward1>) 94800
# tensor(55.0181, grad_fn=<MeanBackward1>) 94900
# tensor(54.9751, grad_fn=<MeanBackward1>) 95000
# tensor(55.0544, grad_fn=<MeanBackward1>) 95100
# tensor(55.0935, grad_fn=<MeanBackward1>) 95200
# tensor(55.0133, grad_fn=<MeanBackward1>) 95300
# tensor(54.9934, grad_fn=<MeanBackward1>) 95400
# tensor(54.9645, grad_fn=<MeanBackward1>) 95500
# tensor(55.0365, grad_fn=<MeanBackward1>) 95600
# tensor(55.1024, grad_fn=<MeanBackward1>) 95700
# tensor(54.9381, grad_fn=<MeanBackward1>) 95800
# tensor(54.9707, grad_fn=<MeanBackward1>) 95900
# tensor(55.0336, grad_fn=<MeanBackward1>) 96000
# tensor(55.0966, grad_fn=<MeanBackward1>) 96100
# tensor(55.1218, grad_fn=<MeanBackward1>) 96200
# tensor(54.8478, grad_fn=<MeanBackward1>) 96300
# tensor(55.0449, grad_fn=<MeanBackward1>) 96400
# tensor(54.9881, grad_fn=<MeanBackward1>) 96500
# tensor(55.0923, grad_fn=<MeanBackward1>) 96600
# tensor(55.0259, grad_fn=<MeanBackward1>) 96700
# tensor(55.1056, grad_fn=<MeanBackward1>) 96800
# tensor(54.9497, grad_fn=<MeanBackward1>) 96900
# tensor(54.9923, grad_fn=<MeanBackward1>) 97000
# tensor(54.9275, grad_fn=<MeanBackward1>) 97100
# tensor(54.9134, grad_fn=<MeanBackward1>) 97200
# tensor(55.0267, grad_fn=<MeanBackward1>) 97300
# tensor(54.9975, grad_fn=<MeanBackward1>) 97400
# tensor(55.0716, grad_fn=<MeanBackward1>) 97500
# tensor(55.0390, grad_fn=<MeanBackward1>) 97600
# tensor(55.0607, grad_fn=<MeanBackward1>) 97700
# tensor(55.0312, grad_fn=<MeanBackward1>) 97800
# tensor(55.0182, grad_fn=<MeanBackward1>) 97900
# tensor(54.9143, grad_fn=<MeanBackward1>) 98000
# tensor(54.9698, grad_fn=<MeanBackward1>) 98100
# tensor(55.1360, grad_fn=<MeanBackward1>) 98200
# tensor(54.9859, grad_fn=<MeanBackward1>) 98300
# tensor(54.8571, grad_fn=<MeanBackward1>) 98400
# tensor(55.0498, grad_fn=<MeanBackward1>) 98500
# tensor(55.0018, grad_fn=<MeanBackward1>) 98600
# tensor(54.9466, grad_fn=<MeanBackward1>) 98700
# tensor(55.0245, grad_fn=<MeanBackward1>) 98800
# tensor(54.9656, grad_fn=<MeanBackward1>) 98900
# tensor(54.8993, grad_fn=<MeanBackward1>) 99000
# tensor(55.0458, grad_fn=<MeanBackward1>) 99100
# tensor(54.9945, grad_fn=<MeanBackward1>) 99200
# tensor(55.0287, grad_fn=<MeanBackward1>) 99300
# tensor(55.0182, grad_fn=<MeanBackward1>) 99400
# tensor(55.0151, grad_fn=<MeanBackward1>) 99500
# tensor(55.1130, grad_fn=<MeanBackward1>) 99600
# tensor(54.9393, grad_fn=<MeanBackward1>) 99700
# tensor(55.0596, grad_fn=<MeanBackward1>) 99800
# tensor(54.9956, grad_fn=<MeanBackward1>) 99900
# tensor(137.3148, grad_fn=<MeanBackward1>) 34400
# tensor(130.4629, grad_fn=<MeanBackward1>) 34500
# tensor(135.0703, grad_fn=<MeanBackward1>) 34600
# tensor(129.0948, grad_fn=<MeanBackward1>) 34700
# tensor(141.4388, grad_fn=<MeanBackward1>) 34800
# tensor(145.9889, grad_fn=<MeanBackward1>) 34900
# tensor(148.0789, grad_fn=<MeanBackward1>) 35000
# tensor(150.3133, grad_fn=<MeanBackward1>) 35100
# tensor(151.0993, grad_fn=<MeanBackward1>) 35200
# tensor(146.2246, grad_fn=<MeanBackward1>) 35300
# tensor(153.7743, grad_fn=<MeanBackward1>) 35400
# tensor(144.2014, grad_fn=<MeanBackward1>) 35500
# tensor(146.3279, grad_fn=<MeanBackward1>) 35600
# tensor(150.0573, grad_fn=<MeanBackward1>) 35700
# tensor(147.2516, grad_fn=<MeanBackward1>) 35800
# tensor(144.0405, grad_fn=<MeanBackward1>) 35900
# tensor(141.4045, grad_fn=<MeanBackward1>) 36000
# tensor(146.5808, grad_fn=<MeanBackward1>) 36100
# tensor(146.4994, grad_fn=<MeanBackward1>) 36200
# tensor(142.8770, grad_fn=<MeanBackward1>) 36300
# tensor(144.8176, grad_fn=<MeanBackward1>) 36400
# tensor(137.8370, grad_fn=<MeanBackward1>) 36500
# tensor(144.2533, grad_fn=<MeanBackward1>) 36600
# ...
# tensor(130.3932, grad_fn=<MeanBackward1>) 67500
# tensor(131.9061, grad_fn=<MeanBackward1>) 67600
# tensor(130.3469, grad_fn=<MeanBackward1>) 67700
# tensor(129.3225, grad_fn=<MeanBackward1>) 67800
# tensor(133.6579, grad_fn=<MeanBackward1>) 67900
# tensor(133.7477, grad_fn=<MeanBackward1>) 68000
# tensor(129.9430, grad_fn=<MeanBackward1>) 68100
# tensor(132.4955, grad_fn=<MeanBackward1>) 68200
# tensor(126.8448, grad_fn=<MeanBackward1>) 68300
# tensor(133.7562, grad_fn=<MeanBackward1>) 68400
# tensor(129.7270, grad_fn=<MeanBackward1>) 68500
# tensor(131.3032, grad_fn=<MeanBackward1>) 68600
# tensor(131.2747, grad_fn=<MeanBackward1>) 68700
# tensor(129.2322, grad_fn=<MeanBackward1>) 68800
# tensor(131.8319, grad_fn=<MeanBackward1>) 68900
# tensor(129.6468, grad_fn=<MeanBackward1>) 69000
# tensor(130.9536, grad_fn=<MeanBackward1>) 69100
# tensor(132.2050, grad_fn=<MeanBackward1>) 69200
# tensor(125.4845, grad_fn=<MeanBackward1>) 69300
# tensor(127.5276, grad_fn=<MeanBackward1>) 69400
# tensor(133.4069, grad_fn=<MeanBackward1>) 69500
# tensor(128.1409, grad_fn=<MeanBackward1>) 69600
# tensor(130.9486, grad_fn=<MeanBackward1>) 69700
# tensor(129.4337, grad_fn=<MeanBackward1>) 69800
# tensor(129.4167, grad_fn=<MeanBackward1>) 69900
# tensor(126.6541, grad_fn=<MeanBackward1>) 70000
# tensor(129.5190, grad_fn=<MeanBackward1>) 70100
# tensor(126.3294, grad_fn=<MeanBackward1>) 70200
# tensor(125.7597, grad_fn=<MeanBackward1>) 70300
# tensor(124.9708, grad_fn=<MeanBackward1>) 70400
# tensor(127.7591, grad_fn=<MeanBackward1>) 70500
# tensor(126.7276, grad_fn=<MeanBackward1>) 70600
# tensor(127.8017, grad_fn=<MeanBackward1>) 70700
# tensor(123.9154, grad_fn=<MeanBackward1>) 70800
# tensor(128.6561, grad_fn=<MeanBackward1>) 70900
# tensor(127.2157, grad_fn=<MeanBackward1>) 71000
# tensor(124.6747, grad_fn=<MeanBackward1>) 71100
# tensor(128.2747, grad_fn=<MeanBackward1>) 71200
# tensor(124.0728, grad_fn=<MeanBackward1>) 71300
# tensor(126.9911, grad_fn=<MeanBackward1>) 71400
# tensor(126.6249, grad_fn=<MeanBackward1>) 71500
# tensor(128.8247, grad_fn=<MeanBackward1>) 71600
# tensor(124.2085, grad_fn=<MeanBackward1>) 71700
# tensor(123.9402, grad_fn=<MeanBackward1>) 71800
# tensor(123.7577, grad_fn=<MeanBackward1>) 71900
# tensor(124.0945, grad_fn=<MeanBackward1>) 72000
# tensor(123.5600, grad_fn=<MeanBackward1>) 72100
# tensor(124.7432, grad_fn=<MeanBackward1>) 72200
# tensor(122.3823, grad_fn=<MeanBackward1>) 72300
# tensor(124.8042, grad_fn=<MeanBackward1>) 72400
# tensor(120.2385, grad_fn=<MeanBackward1>) 72500
# tensor(119.5236, grad_fn=<MeanBackward1>) 72600
# tensor(123.0445, grad_fn=<MeanBackward1>) 72700
# tensor(121.8467, grad_fn=<MeanBackward1>) 72800
# tensor(121.3975, grad_fn=<MeanBackward1>) 72900
# tensor(117.9434, grad_fn=<MeanBackward1>) 73000
# tensor(121.6551, grad_fn=<MeanBackward1>) 73100
# tensor(117.1168, grad_fn=<MeanBackward1>) 73200
# tensor(118.7301, grad_fn=<MeanBackward1>) 73300
# tensor(119.8374, grad_fn=<MeanBackward1>) 73400
# tensor(119.3394, grad_fn=<MeanBackward1>) 73500
# tensor(115.2534, grad_fn=<MeanBackward1>) 73600
# tensor(113.6487, grad_fn=<MeanBackward1>) 73700
# tensor(114.8268, grad_fn=<MeanBackward1>) 73800
# tensor(113.8437, grad_fn=<MeanBackward1>) 73900
# tensor(109.9302, grad_fn=<MeanBackward1>) 74000
# tensor(110.5733, grad_fn=<MeanBackward1>) 74100
# tensor(110.5649, grad_fn=<MeanBackward1>) 74200
# tensor(113.2471, grad_fn=<MeanBackward1>) 74300
# tensor(111.4073, grad_fn=<MeanBackward1>) 74400
# tensor(108.8543, grad_fn=<MeanBackward1>) 74500
# tensor(109.4429, grad_fn=<MeanBackward1>) 74600
# tensor(107.5652, grad_fn=<MeanBackward1>) 74700
# tensor(106.6864, grad_fn=<MeanBackward1>) 74800
# tensor(108.0378, grad_fn=<MeanBackward1>) 74900
# tensor(105.7468, grad_fn=<MeanBackward1>) 75000
# tensor(105.6025, grad_fn=<MeanBackward1>) 75100
# tensor(105.3826, grad_fn=<MeanBackward1>) 75200
# tensor(102.5744, grad_fn=<MeanBackward1>) 75300
# tensor(101.2974, grad_fn=<MeanBackward1>) 75400
# tensor(98.7060, grad_fn=<MeanBackward1>) 75500
# tensor(98.5267, grad_fn=<MeanBackward1>) 75600
# tensor(97.3120, grad_fn=<MeanBackward1>) 75700
# tensor(99.1359, grad_fn=<MeanBackward1>) 75800
# tensor(96.9968, grad_fn=<MeanBackward1>) 75900
# tensor(94.6883, grad_fn=<MeanBackward1>) 76000
# tensor(94.3467, grad_fn=<MeanBackward1>) 76100
# tensor(93.1395, grad_fn=<MeanBackward1>) 76200
# tensor(91.6006, grad_fn=<MeanBackward1>) 76300
# tensor(91.2408, grad_fn=<MeanBackward1>) 76400
# tensor(90.3105, grad_fn=<MeanBackward1>) 76500
# tensor(89.8960, grad_fn=<MeanBackward1>) 76600
# tensor(87.3480, grad_fn=<MeanBackward1>) 76700
# tensor(86.7135, grad_fn=<MeanBackward1>) 76800
# tensor(86.0985, grad_fn=<MeanBackward1>) 76900
# tensor(84.4857, grad_fn=<MeanBackward1>) 77000
# tensor(84.5508, grad_fn=<MeanBackward1>) 77100
# tensor(83.1357, grad_fn=<MeanBackward1>) 77200
# tensor(82.1340, grad_fn=<MeanBackward1>) 77300
# tensor(81.3062, grad_fn=<MeanBackward1>) 77400
# tensor(80.6557, grad_fn=<MeanBackward1>) 77500
# tensor(79.3332, grad_fn=<MeanBackward1>) 77600
# tensor(78.3836, grad_fn=<MeanBackward1>) 77700
# tensor(75.6991, grad_fn=<MeanBackward1>) 77800
# tensor(74.4459, grad_fn=<MeanBackward1>) 77900
# tensor(74.6091, grad_fn=<MeanBackward1>) 78000
# tensor(73.9072, grad_fn=<MeanBackward1>) 78100
# tensor(72.5047, grad_fn=<MeanBackward1>) 78200
# tensor(71.9041, grad_fn=<MeanBackward1>) 78300
# tensor(70.9791, grad_fn=<MeanBackward1>) 78400
# tensor(79.0493, grad_fn=<MeanBackward1>) 78500
# tensor(78.4003, grad_fn=<MeanBackward1>) 78600
# tensor(77.2092, grad_fn=<MeanBackward1>) 78700
# tensor(74.6980, grad_fn=<MeanBackward1>) 78800
# tensor(73.5044, grad_fn=<MeanBackward1>) 78900
# tensor(1.0185e+25, grad_fn=<MeanBackward1>) 79000
# tensor(8.3972e+26, grad_fn=<MeanBackward1>) 79100
# tensor(2.9245e+27, grad_fn=<MeanBackward1>) 79200
# tensor(3.9240e+22, grad_fn=<MeanBackward1>) 79300
# tensor(5.8098e+26, grad_fn=<MeanBackward1>) 79400
# tensor(3.7019e+23, grad_fn=<MeanBackward1>) 79500
# tensor(5.7616e+23, grad_fn=<MeanBackward1>) 79600
# tensor(1.3840e+23, grad_fn=<MeanBackward1>) 79700
# tensor(1.0192e+24, grad_fn=<MeanBackward1>) 79800
# tensor(2.1640e+26, grad_fn=<MeanBackward1>) 79900
# tensor(5.1514e+21, grad_fn=<MeanBackward1>) 80000
# tensor(4.2149e+21, grad_fn=<MeanBackward1>) 80100
# tensor(2.8573e+24, grad_fn=<MeanBackward1>) 80200
# tensor(1.7278e+21, grad_fn=<MeanBackward1>) 80300
# tensor(4.5817e+21, grad_fn=<MeanBackward1>) 80400
# tensor(9.5145e+21, grad_fn=<MeanBackward1>) 80500
# tensor(8.2215e+23, grad_fn=<MeanBackward1>) 80600
# tensor(7.9126e+26, grad_fn=<MeanBackward1>) 80700
# tensor(2.8586e+21, grad_fn=<MeanBackward1>) 80800
# tensor(3.4091e+24, grad_fn=<MeanBackward1>) 80900
# tensor(3.3601e+25, grad_fn=<MeanBackward1>) 81000
# tensor(6.8064e+25, grad_fn=<MeanBackward1>) 81100
# tensor(1.9637e+22, grad_fn=<MeanBackward1>) 81200
# tensor(5.5675e+25, grad_fn=<MeanBackward1>) 81300
# tensor(1.9931e+25, grad_fn=<MeanBackward1>) 81400
# tensor(1.1176e+23, grad_fn=<MeanBackward1>) 81500
# tensor(7.1925e+26, grad_fn=<MeanBackward1>) 81600
# tensor(3.1115e+25, grad_fn=<MeanBackward1>) 81700
# tensor(5.6989e+21, grad_fn=<MeanBackward1>) 81800
# tensor(1.2035e+23, grad_fn=<MeanBackward1>) 81900
# tensor(3.2341e+26, grad_fn=<MeanBackward1>) 82000
# tensor(1.8329e+24, grad_fn=<MeanBackward1>) 82100
# tensor(3.4087e+25, grad_fn=<MeanBackward1>) 82200
# tensor(1.1567e+22, grad_fn=<MeanBackward1>) 82300
# tensor(7.9200e+25, grad_fn=<MeanBackward1>) 82400
# tensor(1.4296e+25, grad_fn=<MeanBackward1>) 82500
# tensor(2.9204e+25, grad_fn=<MeanBackward1>) 82600
# tensor(3.1988e+22, grad_fn=<MeanBackward1>) 82700
# tensor(9.4588e+25, grad_fn=<MeanBackward1>) 82800
# tensor(3.3334e+25, grad_fn=<MeanBackward1>) 82900
# tensor(1.0281e+23, grad_fn=<MeanBackward1>) 83000
# tensor(3.6418e+27, grad_fn=<MeanBackward1>) 83100
# tensor(8.1830e+24, grad_fn=<MeanBackward1>) 83200
# tensor(1.5028e+26, grad_fn=<MeanBackward1>) 83300
# tensor(2.8907e+24, grad_fn=<MeanBackward1>) 83400
# tensor(5.1329e+23, grad_fn=<MeanBackward1>) 83500
# tensor(1.7952e+23, grad_fn=<MeanBackward1>) 83600
# tensor(3.1167e+24, grad_fn=<MeanBackward1>) 83700
# tensor(8.8170e+23, grad_fn=<MeanBackward1>) 83800
# tensor(1.6654e+24, grad_fn=<MeanBackward1>) 83900
# tensor(8.9381e+23, grad_fn=<MeanBackward1>) 84000
# tensor(1.5494e+27, grad_fn=<MeanBackward1>) 84100
# tensor(4.5721e+24, grad_fn=<MeanBackward1>) 84200
# tensor(7.0852e+22, grad_fn=<MeanBackward1>) 84300
# tensor(6.6232e+22, grad_fn=<MeanBackward1>) 84400
# tensor(3.4699e+21, grad_fn=<MeanBackward1>) 84500
# tensor(1.6052e+23, grad_fn=<MeanBackward1>) 84600
# tensor(4.0769e+26, grad_fn=<MeanBackward1>) 84700
# tensor(2.9307e+27, grad_fn=<MeanBackward1>) 84800
# tensor(2.7084e+20, grad_fn=<MeanBackward1>) 84900
# tensor(1.8210e+26, grad_fn=<MeanBackward1>) 85000
# tensor(1.4620e+23, grad_fn=<MeanBackward1>) 85100
# tensor(1.2469e+23, grad_fn=<MeanBackward1>) 85200
# tensor(1.9184e+27, grad_fn=<MeanBackward1>) 85300
# tensor(2.2017e+26, grad_fn=<MeanBackward1>) 85400
# tensor(1.1825e+27, grad_fn=<MeanBackward1>) 85500
# tensor(8.8467e+25, grad_fn=<MeanBackward1>) 85600
# tensor(2.1808e+25, grad_fn=<MeanBackward1>) 85700
# tensor(2.1409e+26, grad_fn=<MeanBackward1>) 85800
# tensor(4.6276e+24, grad_fn=<MeanBackward1>) 85900
# tensor(4.4444e+25, grad_fn=<MeanBackward1>) 86000
# tensor(8.1156e+26, grad_fn=<MeanBackward1>) 86100
# tensor(5.7200e+26, grad_fn=<MeanBackward1>) 86200
# tensor(5.6219e+22, grad_fn=<MeanBackward1>) 86300
# tensor(3.0163e+20, grad_fn=<MeanBackward1>) 86400
# tensor(9.5646e+25, grad_fn=<MeanBackward1>) 86500
# tensor(8.7808e+26, grad_fn=<MeanBackward1>) 86600
# tensor(2.4252e+26, grad_fn=<MeanBackward1>) 86700
# tensor(1.3752e+25, grad_fn=<MeanBackward1>) 86800
# tensor(3.4258e+24, grad_fn=<MeanBackward1>) 86900
# tensor(4.6189e+24, grad_fn=<MeanBackward1>) 87000
# tensor(4.4419e+25, grad_fn=<MeanBackward1>) 87100
# tensor(1.3381e+25, grad_fn=<MeanBackward1>) 87200
# tensor(2.3037e+24, grad_fn=<MeanBackward1>) 87300
# tensor(2.2429e+24, grad_fn=<MeanBackward1>) 87400
# tensor(1.6087e+25, grad_fn=<MeanBackward1>) 87500
# tensor(1.9650e+23, grad_fn=<MeanBackward1>) 87600
# tensor(4.9525e+23, grad_fn=<MeanBackward1>) 87700
# tensor(1.9354e+24, grad_fn=<MeanBackward1>) 87800
# tensor(2.6834e+25, grad_fn=<MeanBackward1>) 87900
# tensor(1.4296e+23, grad_fn=<MeanBackward1>) 88000
# tensor(1.2638e+24, grad_fn=<MeanBackward1>) 88100
# tensor(1.3548e+22, grad_fn=<MeanBackward1>) 88200
# tensor(6.8334e+22, grad_fn=<MeanBackward1>) 88300
# tensor(9.2831e+24, grad_fn=<MeanBackward1>) 88400
# tensor(1.0746e+24, grad_fn=<MeanBackward1>) 88500
# tensor(2.1715e+23, grad_fn=<MeanBackward1>) 88600
# tensor(1.4204e+24, grad_fn=<MeanBackward1>) 88700
# tensor(3.4242e+25, grad_fn=<MeanBackward1>) 88800
# tensor(6.3405e+26, grad_fn=<MeanBackward1>) 88900
# tensor(9.1959e+26, grad_fn=<MeanBackward1>) 89000
# tensor(6.5198e+26, grad_fn=<MeanBackward1>) 89100
# tensor(2.1046e+25, grad_fn=<MeanBackward1>) 89200
# tensor(4.9819e+26, grad_fn=<MeanBackward1>) 89300
# tensor(8.2215e+21, grad_fn=<MeanBackward1>) 89400
# tensor(5.2944e+22, grad_fn=<MeanBackward1>) 89500
# tensor(9.9936e+23, grad_fn=<MeanBackward1>) 89600
# tensor(7.1792e+25, grad_fn=<MeanBackward1>) 89700
# tensor(2.7589e+24, grad_fn=<MeanBackward1>) 89800
# tensor(2.2299e+25, grad_fn=<MeanBackward1>) 89900
# tensor(3.9983e+26, grad_fn=<MeanBackward1>) 90000
# tensor(1.3196e+27, grad_fn=<MeanBackward1>) 90100
# tensor(2.9315e+24, grad_fn=<MeanBackward1>) 90200
# tensor(1.3080e+27, grad_fn=<MeanBackward1>) 90300
# tensor(4.6160e+22, grad_fn=<MeanBackward1>) 90400
# tensor(7.6492e+22, grad_fn=<MeanBackward1>) 90500
# tensor(3.8681e+22, grad_fn=<MeanBackward1>) 90600
# tensor(4.7806e+23, grad_fn=<MeanBackward1>) 90700
# tensor(4.1042e+23, grad_fn=<MeanBackward1>) 90800
# tensor(3.5852e+22, grad_fn=<MeanBackward1>) 90900
# tensor(1.7223e+24, grad_fn=<MeanBackward1>) 91000
# tensor(9.6787e+23, grad_fn=<MeanBackward1>) 91100
# tensor(5.2800e+25, grad_fn=<MeanBackward1>) 91200
# tensor(7.2157e+26, grad_fn=<MeanBackward1>) 91300
# tensor(1.4632e+26, grad_fn=<MeanBackward1>) 91400
# tensor(2.5407e+24, grad_fn=<MeanBackward1>) 91500
# tensor(1.0435e+27, grad_fn=<MeanBackward1>) 91600
# tensor(7.8316e+21, grad_fn=<MeanBackward1>) 91700
# tensor(7.0852e+24, grad_fn=<MeanBackward1>) 91800
# tensor(7.5114e+26, grad_fn=<MeanBackward1>) 91900
# tensor(1.5370e+26, grad_fn=<MeanBackward1>) 92000
# tensor(1.4971e+22, grad_fn=<MeanBackward1>) 92100
# tensor(1.3045e+22, grad_fn=<MeanBackward1>) 92200
# tensor(3.8137e+26, grad_fn=<MeanBackward1>) 92300
# tensor(2.1138e+21, grad_fn=<MeanBackward1>) 92400
# tensor(1.7815e+26, grad_fn=<MeanBackward1>) 92500
# tensor(4.6495e+25, grad_fn=<MeanBackward1>) 92600
# tensor(3.8938e+21, grad_fn=<MeanBackward1>) 92700
# tensor(5.0873e+25, grad_fn=<MeanBackward1>) 92800
# tensor(2.0301e+24, grad_fn=<MeanBackward1>) 92900
# tensor(6.7940e+22, grad_fn=<MeanBackward1>) 93000
# tensor(1.7254e+25, grad_fn=<MeanBackward1>) 93100
# tensor(1.3074e+24, grad_fn=<MeanBackward1>) 93200
# tensor(4.1998e+25, grad_fn=<MeanBackward1>) 93300
# tensor(1.2373e+24, grad_fn=<MeanBackward1>) 93400
# tensor(3.4792e+23, grad_fn=<MeanBackward1>) 93500
# tensor(4.3126e+25, grad_fn=<MeanBackward1>) 93600
# tensor(7.3411e+21, grad_fn=<MeanBackward1>) 93700
# tensor(7.6996e+20, grad_fn=<MeanBackward1>) 93800
# tensor(2.2915e+22, grad_fn=<MeanBackward1>) 93900
# tensor(3.7479e+21, grad_fn=<MeanBackward1>) 94000
# tensor(1.2838e+24, grad_fn=<MeanBackward1>) 94100
# tensor(1.5670e+22, grad_fn=<MeanBackward1>) 94200
# tensor(3.0323e+25, grad_fn=<MeanBackward1>) 94300
# tensor(1.7937e+23, grad_fn=<MeanBackward1>) 94400
# tensor(2.7513e+20, grad_fn=<MeanBackward1>) 94500
# tensor(3.3747e+26, grad_fn=<MeanBackward1>) 94600
# tensor(5.1423e+26, grad_fn=<MeanBackward1>) 94700
# tensor(5.3181e+21, grad_fn=<MeanBackward1>) 94800
# tensor(7.8702e+24, grad_fn=<MeanBackward1>) 94900
# tensor(1.3293e+22, grad_fn=<MeanBackward1>) 95000
# tensor(2.1885e+26, grad_fn=<MeanBackward1>) 95100
# tensor(1.0123e+22, grad_fn=<MeanBackward1>) 95200
# tensor(2.7950e+21, grad_fn=<MeanBackward1>) 95300
# tensor(1.3412e+23, grad_fn=<MeanBackward1>) 95400
# tensor(1.4764e+24, grad_fn=<MeanBackward1>) 95500
# tensor(1.4017e+23, grad_fn=<MeanBackward1>) 95600
# tensor(1.5211e+26, grad_fn=<MeanBackward1>) 95700
# tensor(3.8098e+26, grad_fn=<MeanBackward1>) 95800
# tensor(2.5707e+24, grad_fn=<MeanBackward1>) 95900
# tensor(1.8312e+25, grad_fn=<MeanBackward1>) 96000
# tensor(5.7981e+25, grad_fn=<MeanBackward1>) 96100
# tensor(2.3013e+26, grad_fn=<MeanBackward1>) 96200
# tensor(1.1299e+26, grad_fn=<MeanBackward1>) 96300
# tensor(2.8512e+24, grad_fn=<MeanBackward1>) 96400
# tensor(2.2156e+26, grad_fn=<MeanBackward1>) 96500
# tensor(1.0384e+27, grad_fn=<MeanBackward1>) 96600
# tensor(2.8994e+25, grad_fn=<MeanBackward1>) 96700
# tensor(1.1466e+25, grad_fn=<MeanBackward1>) 96800
# tensor(1.7317e+22, grad_fn=<MeanBackward1>) 96900
# tensor(1.1083e+23, grad_fn=<MeanBackward1>) 97000
# tensor(1.9429e+22, grad_fn=<MeanBackward1>) 97100
# tensor(5.2246e+23, grad_fn=<MeanBackward1>) 97200
# tensor(4.0420e+23, grad_fn=<MeanBackward1>) 97300
# tensor(3.4624e+24, grad_fn=<MeanBackward1>) 97400
# tensor(2.4957e+25, grad_fn=<MeanBackward1>) 97500
# tensor(2.8312e+25, grad_fn=<MeanBackward1>) 97600
# tensor(3.3648e+26, grad_fn=<MeanBackward1>) 97700
# tensor(1.2334e+26, grad_fn=<MeanBackward1>) 97800
# tensor(1.4939e+25, grad_fn=<MeanBackward1>) 97900
# tensor(2.1662e+24, grad_fn=<MeanBackward1>) 98000
# tensor(9.0861e+24, grad_fn=<MeanBackward1>) 98100
# tensor(7.2034e+25, grad_fn=<MeanBackward1>) 98200
# tensor(3.5277e+21, grad_fn=<MeanBackward1>) 98300
# tensor(1.5952e+23, grad_fn=<MeanBackward1>) 98400
# tensor(2.2958e+22, grad_fn=<MeanBackward1>) 98500
# tensor(2.2602e+24, grad_fn=<MeanBackward1>) 98600
# tensor(3.3462e+23, grad_fn=<MeanBackward1>) 98700
# tensor(3.5588e+25, grad_fn=<MeanBackward1>) 98800
# tensor(8.2566e+25, grad_fn=<MeanBackward1>) 98900
# tensor(3.9425e+24, grad_fn=<MeanBackward1>) 99000
# tensor(5.0826e+23, grad_fn=<MeanBackward1>) 99100
# tensor(1.1648e+27, grad_fn=<MeanBackward1>) 99200
# tensor(1.9330e+22, grad_fn=<MeanBackward1>) 99300
# tensor(2.4884e+21, grad_fn=<MeanBackward1>) 99400
# tensor(1.2279e+24, grad_fn=<MeanBackward1>) 99500
# tensor(1.9055e+24, grad_fn=<MeanBackward1>) 99600
# tensor(5.5711e+26, grad_fn=<MeanBackward1>) 99700
# tensor(1.8477e+24, grad_fn=<MeanBackward1>) 99800
# tensor(2.0039e+25, grad_fn=<MeanBackward1>) 99900

# %% [markdown]
# SDE simulation functions

# %%
# This is the solving the VE process exactly given deterministic initial conditions
def ve_dynamics(init, sigma_min, sigma_max, T=1.0):
    init = init + sigma_max * torch.randn_like(init)
    return init
    
def reverse_sde(score, init, sigma_min, sigma_max, T=1.0, lr=0.01):
    step = int(T/lr)
    for i in range(step,-1,-1):
        evalpoint = torch.cat(((torch.tensor(lr*i/T)).repeat(init.shape[0],1),init),1)
        drift = torch.zeros_like(evalpoint)
        sigma = sigma_min *(sigma_max/sigma_min)**(i*lr/T)
        diffusion = sigma * torch.sqrt(2*(torch.log(sigma_max)-torch.log(sigma_min)))
        
        init = init + lr  * diffusion**2 * score(evalpoint).detach() 
        init = init + diffusion * torch.randn_like(init) * np.sqrt(lr)
    return init



# The following is the deterministic ODE flow that can also sample from the target distribution

def reverse_ode_flow(score,init, sigma_min, sigma_max, T=1.0, lr = 0.01):
    step = int(T/lr)
    for i in range(step,-1,-1):
        evalpoint = torch.cat(((torch.tensor(lr*i/T)).repeat(init.shape[0],1),init),1)
        sigma = sigma_min *(sigma_max/sigma_min)**(i*lr/T)
        diffusion = sigma * torch.sqrt(2*(torch.log(sigma_max)-torch.log(sigma_min)))
        
        init = init + lr/2* diffusion**2 * score(evalpoint).detach() 
    return init

# %% [markdown]
# Sample using the score network

# %%
# Denoising the normal distribution 
samples_lang = torch.randn(10000, d+d_orth)*sigma_max # * (right_bound - left_bound) + left_bound
samples_lang = reverse_sde(scorenet, samples_lang, torch.tensor(sigma_min), torch.tensor(sigma_max)).detach().numpy()


p_samples = toy_data.inf_train_gen(dataset, batch_size = 10000)
ve_samples = ve_dynamics(torch.tensor(p_samples).to(dtype = torch.float32),  torch.tensor(sigma_min), torch.tensor(sigma_max))

# %%
plt.clf()
p_samples = toy_data.inf_train_gen(dataset, batch_size = 10000, misc_params={})
ve_samples = ve_dynamics(torch.tensor(p_samples).to(dtype = torch.float32),  torch.tensor(sigma_min), torch.tensor(sigma_max))
plt.scatter(ve_samples[:,0],ve_samples[:,1],s = 0.1)
plt.axis('square')
plt.title('Samples from VE process')
plt.show()


plt.clf()
p_samples = toy_data.inf_train_gen(dataset, batch_size = 10000, misc_params={})
samples_true = torch.tensor(p_samples).to(dtype = torch.float32)
plt.scatter(samples_true[:,0],samples_true[:,1],s = 0.1)
plt.axis('square')
plt.title('True samples')
plt.show()


plt.clf()
plt.scatter(samples_lang[:,0],samples_lang[:,1],s = 0.1)
plt.axis('square')
plt.title('Samples from reverse SDE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 2
#       1 plt.clf()
# ----> 2 p_samples = toy_data.inf_train_gen(dataset, batch_size = 10000, misc_params={'df':df})
#       3 ve_samples = ve_dynamics(torch.tensor(p_samples).to(dtype = torch.float32),  torch.tensor(sigma_min), torch.tensor(sigma_max))
#       4 plt.scatter(ve_samples[:,0],ve_samples[:,1],s = 0.1)
#
# NameError: name 'df' is not defined

# %%
filename = f"../../assets/{dataset}/ve_sgm_heavytail_submanifold_{N_samples}samples.pickle"
with open(filename,"wb") as fw:
    pickle.dump([ve_samples, samples_lang] , fw)
